# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import math
import seaborn as sns

import sklearn
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
sklearn.__version__
# Out:
# '0.21.2'

# %% [markdown]
# ## LendingClub Data Acquisition

# %%
# raw_q12019 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2019Q1.csv',header=1)
# raw_q42018 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2018Q4.csv',header=1)
# raw_q32018 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2018Q3.csv',header=1)
# raw_q22018 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2018Q2.csv',header=1)
# raw_q12018 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2018Q1.csv',header=1)
raw_q42017 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2017Q4.csv',header=1)
raw_q32017 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2017Q3.csv',header=1)
raw_q22017 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2017Q2.csv',header=1)
raw_q12017 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2017Q1.csv',header=1)
raw_q42016 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2016Q4.csv',header=1)
raw_q32016 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2016Q3.csv',header=1)
raw_q22016 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2016Q2.csv',header=1)
raw_q12016 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2016Q1.csv',header=1)
raw_2015 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2015.csv',header=1)
raw_2014 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2014.csv',header=1)
raw_2012to2013 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2012to2013.csv',header=1)
raw_2007to2011 = pd.read_csv('~/peervest/lc_data/LoanStats_securev1_2007to2011.csv',header=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,19,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,19,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,49,129,130,131,134,135,136,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (0,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# print(raw_q12019.shape)
# print(raw_q42018.shape)
# print(raw_q32018.shape)
# print(raw_q22018.shape)
# print(raw_q12018.shape)
print(raw_q42017.shape)
print(raw_q32017.shape)
print(raw_q22017.shape)
print(raw_q12017.shape)
print(raw_q42016.shape)
print(raw_q32016.shape)
print(raw_q22016.shape)
print(raw_q12016.shape)
print(raw_2015.shape)
print(raw_2014.shape)
print(raw_2012to2013.shape)
print(raw_2007to2011.shape)
#raw_q12019,raw_q42018,raw_q32018,raw_q22018,raw_q12018,
dfs = [raw_q42017,raw_q32017,raw_q22017,raw_q12017,
       raw_q42016,raw_q32016,raw_q22016,raw_q12016,raw_2015,
       raw_2014,raw_2012to2013, raw_2007to2011]
# Out:
# (118650, 150)
# (122703, 150)
# (105453, 150)
# (96781, 150)
# (103548, 150)
# (99122, 150)
# (97856, 150)
# (133889, 150)
# (421097, 150)
# (235631, 150)
# (188183, 150)
# (42538, 150)

# %%
raw_lc_df = pd.concat(dfs,ignore_index=True).set_index('id')

# %%
raw_lc_df
# Out:
#                                                  member_id  loan_amnt  \
# id
# 126065224                                              NaN     9600.0
# 126413271                                              NaN    25000.0
# 126176997                                              NaN    30000.0
# 126389018                                              NaN    35000.0
# 126406926                                              NaN     6000.0
# 125602675                                              NaN    13000.0
# 126154990                                              NaN     4000.0
# 126417318                                              NaN    15000.0
# 126410177                                              NaN     6500.0
# 125193750                                              NaN     5000.0
# 126338469                                              NaN    25000.0
# 126383696                                              NaN    10000.0
# 126309246                                              NaN     8000.0
# 126189493                                              NaN    24000.0
# 126419316                                              NaN    20000.0
# 125149625                                              NaN    10000.0
# 126309870                                              NaN    20000.0
# 126407653                                              NaN    15750.0
# 125907898                                              NaN    20000.0
# 125566359                                              NaN    10200.0
# 126273452                                              NaN    19800.0
# 126171880                                              NaN     8400.0
# 126365454                                              NaN    12000.0
# 126412424                                              NaN    10000.0
# 126193806                                              NaN    24000.0
# 126406609                                              NaN    20000.0
# 126414344                                              NaN     5000.0
# 125490256                                              NaN    16000.0
# 126165519                                              NaN     4800.0
# 126417216                                              NaN    25000.0
# ...                                                    ...        ...
# 91175                                                  NaN     6000.0
# 91126                                                  NaN     5350.0
# 91023                                                  NaN     1900.0
# 90106                                                  NaN    10000.0
# 89258                                                  NaN     2000.0
# 88637                                                  NaN     6000.0
# 88046                                                  NaN     4400.0
# 85961                                                  NaN     1200.0
# 85818                                                  NaN     5000.0
# 85781                                                  NaN     1400.0
# 85675                                                  NaN     1000.0
# 84670                                                  NaN     5000.0
# 84098                                                  NaN     2500.0
# 83979                                                  NaN     3000.0
# 83489                                                  NaN     2600.0
# 83185                                                  NaN     1000.0
# 74014                                                  NaN     6450.0
# 76629                                                  NaN     1275.0
# 81085                                                  NaN    10500.0
# 77792                                                  NaN     3000.0
# 77757                                                  NaN     3000.0
# 74505                                                  NaN     2000.0
# 74323                                                  NaN     6500.0
# 73582                                                  NaN     3500.0
# 72998                                                  NaN     1000.0
# 72176                                                  NaN     2525.0
# 71623                                                  NaN     6500.0
# 70686                                                  NaN     5000.0
# Total amount funded in policy code 1: 460296150        NaN        NaN
# Total amount funded in policy code 2: 0                NaN        NaN
#
#                                                  funded_amnt  funded_amnt_inv  \
# id
# 126065224                                             9600.0           9600.0
# 126413271                                            25000.0          25000.0
# 126176997                                            30000.0          30000.0
# 126389018                                            35000.0          35000.0
# 126406926                                             6000.0           6000.0
# 125602675                                            13000.0          13000.0
# 126154990                                             4000.0           4000.0
# 126417318                                            15000.0          15000.0
# 126410177                                             6500.0           6500.0
# 125193750                                             5000.0           5000.0
# 126338469                                            25000.0          25000.0
# 126383696                                            10000.0          10000.0
# 126309246                                             8000.0           8000.0
# 126189493                                            24000.0          24000.0
# 126419316                                            20000.0          20000.0
# 125149625                                            10000.0          10000.0
# 126309870                                            20000.0          20000.0
# 126407653                                            15750.0          15750.0
# 125907898                                            20000.0          20000.0
# 125566359                                            10200.0          10200.0
# 126273452                                            19800.0          19800.0
# 126171880                                             8400.0           8400.0
# 126365454                                            12000.0          12000.0
# 126412424                                            10000.0          10000.0
# 126193806                                            24000.0          24000.0
# 126406609                                            20000.0          20000.0
# 126414344                                             5000.0           5000.0
# 125490256                                            16000.0          16000.0
# 126165519                                             4800.0           4800.0
# 126417216                                            25000.0          25000.0
# ...                                                      ...              ...
# 91175                                                 6000.0           1200.0
# 91126                                                 5350.0            625.0
# 91023                                                 1900.0            900.0
# 90106                                                10000.0            350.0
# 89258                                                 2000.0           1275.0
# 88637                                                 6000.0            650.0
# 88046                                                 4400.0           1400.0
# 85961                                                 1200.0            500.0
# 85818                                                 5000.0            375.0
# 85781                                                 1400.0            475.0
# 85675                                                 1000.0            625.0
# 84670                                                 5000.0            300.0
# 84098                                                 2500.0            225.0
# 83979                                                 3000.0            250.0
# 83489                                                 2600.0            575.0
# 83185                                                 1000.0            625.0
# 74014                                                 6450.0              0.0
# 76629                                                 1275.0              0.0
# 81085                                                10500.0            275.0
# 77792                                                 3000.0            125.0
# 77757                                                 3000.0              0.0
# 74505                                                 2000.0            225.0
# 74323                                                 6500.0              0.0
# 73582                                                 3500.0            225.0
# 72998                                                 1000.0              0.0
# 72176                                                 2525.0            225.0
# 71623                                                 6500.0              0.0
# 70686                                                 5000.0              0.0
# Total amount funded in policy code 1: 460296150          NaN              NaN
# Total amount funded in policy code 2: 0                  NaN              NaN
#
#                                                        term int_rate  \
# id
# 126065224                                         36 months   11.99%
# 126413271                                         60 months   12.62%
# 126176997                                         60 months   30.79%
# 126389018                                         60 months   11.99%
# 126406926                                         36 months    9.44%
# 125602675                                         60 months   15.05%
# 126154990                                         36 months   10.42%
# 126417318                                         36 months   10.42%
# 126410177                                         36 months    7.35%
# 125193750                                         36 months   22.91%
# 126338469                                         36 months    6.72%
# 126383696                                         36 months    9.93%
# 126309246                                         36 months    9.93%
# 126189493                                         60 months   13.59%
# 126419316                                         60 months   16.02%
# 125149625                                         60 months   10.42%
# 126309870                                         36 months    6.72%
# 126407653                                         36 months    7.35%
# 125907898                                         36 months    9.93%
# 125566359                                         36 months    9.93%
# 126273452                                         60 months   15.05%
# 126171880                                         36 months   18.06%
# 126365454                                         36 months    6.72%
# 126412424                                         36 months    5.32%
# 126193806                                         36 months    7.97%
# 126406609                                         36 months    6.08%
# 126414344                                         36 months    7.35%
# 125490256                                         36 months    7.97%
# 126165519                                         36 months   18.06%
# 126417216                                         60 months   17.09%
# ...                                                     ...      ...
# 91175                                             36 months   13.12%
# 91126                                             36 months   13.12%
# 91023                                             36 months    9.64%
# 90106                                             36 months   14.70%
# 89258                                             36 months    7.12%
# 88637                                             36 months   10.59%
# 88046                                             36 months    9.64%
# 85961                                             36 months    9.01%
# 85818                                             36 months   11.22%
# 85781                                             36 months   10.91%
# 85675                                             36 months   14.07%
# 84670                                             36 months    7.75%
# 84098                                             36 months    7.43%
# 83979                                             36 months    7.43%
# 83489                                             36 months    8.38%
# 83185                                             36 months    7.12%
# 74014                                             36 months   11.22%
# 76629                                             36 months   12.49%
# 81085                                             36 months   11.22%
# 77792                                             36 months    9.01%
# 77757                                             36 months    9.33%
# 74505                                             36 months    9.96%
# 74323                                             36 months    9.64%
# 73582                                             36 months   10.28%
# 72998                                             36 months    9.64%
# 72176                                             36 months    9.33%
# 71623                                             36 months    8.38%
# 70686                                             36 months    7.75%
# Total amount funded in policy code 1: 460296150         NaN      NaN
# Total amount funded in policy code 2: 0                 NaN      NaN
#
#                                                  installment grade sub_grade  \
# id
# 126065224                                             318.82     B        B5
# 126413271                                             563.98     C        C1
# 126176997                                             985.21     G        G1
# 126389018                                             778.38     B        B5
# 126406926                                             192.03     B        B1
# 125602675                                             309.62     C        C4
# 126154990                                             129.86     B        B3
# 126417318                                             486.98     B        B3
# 126410177                                             201.75     A        A4
# 125193750                                             193.32     E        E1
# 126338469                                             768.74     A        A3
# 126383696                                             322.35     B        B2
# 126309246                                             257.88     B        B2
# 126189493                                             553.35     C        C2
# 126419316                                             486.58     C        C5
# 125149625                                             214.55     B        B3
# 126309870                                             614.99     A        A3
# 126407653                                             488.84     A        A4
# 125907898                                             644.69     B        B2
# 125566359                                             328.80     B        B2
# 126273452                                             471.57     C        C4
# 126171880                                             303.94     D        D2
# 126365454                                             369.00     A        A3
# 126412424                                             301.15     A        A1
# 126193806                                             751.75     A        A5
# 126406609                                             609.17     A        A2
# 126414344                                             155.19     A        A4
# 125490256                                             501.17     A        A5
# 126165519                                             173.68     D        D2
# 126417216                                             622.53     D        D1
# ...                                                      ...   ...       ...
# 91175                                                 202.51     D        D5
# 91126                                                 180.57     D        D5
# 91023                                                  61.00     B        B4
# 90106                                                 345.18     E        E5
# 89258                                                  61.87     A        A1
# 88637                                                 195.28     C        C2
# 88046                                                 141.25     B        B4
# 85961                                                  38.17     B        B2
# 85818                                                 164.23     C        C4
# 85781                                                  45.78     C        C3
# 85675                                                  34.21     E        E3
# 84670                                                 156.11     A        A3
# 84098                                                  77.69     A        A2
# 83979                                                  93.23     A        A2
# 83489                                                  81.94     A        A5
# 83185                                                  30.94     A        A1
# 74014                                                 211.85     C        C4
# 76629                                                  42.65     D        D3
# 81085                                                 344.87     C        C4
# 77792                                                  95.42     B        B2
# 77757                                                  95.86     B        B3
# 74505                                                  64.50     B        B5
# 74323                                                 208.66     B        B4
# 73582                                                 113.39     C        C1
# 72998                                                  32.11     B        B4
# 72176                                                  80.69     B        B3
# 71623                                                 204.84     A        A5
# 70686                                                 156.11     A        A3
# Total amount funded in policy code 1: 460296150          NaN   NaN       NaN
# Total amount funded in policy code 2: 0                  NaN   NaN       NaN
#
#                                                                                      emp_title  \
# id
# 126065224                                                                       UXO Technician
# 126413271                                                               Practice Administrator
# 126176997                                                                           Supervsir
# 126389018                                                                     Project Manager
# 126406926                                                            Clinical Program Manager
# 125602675                                                                        Sales manager
# 126154990                                                                               Driver
# 126417318                                                                              Finance
# 126410177                                                                              Manager
# 125193750                                                                           IT Manager
# 126338469                                                                       Office Manager
# 126383696                                                                           Inspector
# 126309246                                                                  Pharmacy Technician
# 126189493                                              Prospective Payment System Coordinator
# 126419316                                                               Tractor Trailer Driver
# 125149625                                                                    Software Engineer
# 126309870                                                                            Installer
# 126407653                                                                  Service Coordinator
# 125907898                                                                       Vice President
# 125566359                                                                  Executive Assistant
# 126273452                                                                             engineer
# 126171880                                                                              Welder
# 126365454                                                                      Project Manager
# 126412424                                                                            Paralegal
# 126193806                                                          Senior Valuation Consultant
# 126406609                                                            Software Support Engineer
# 126414344                                                                respiratory therapist
# 125490256                                                       Associate to Database Services
# 126165519                                                                           Management
# 126417216                                                                     Business Analyst
# ...                                                                                        ...
# 91175                                                                                SUNY- ESF
# 91126                                                    Clinton Shop Rite of Hunterdon County
# 91023                                                                                Scheduall
# 90106                                                                                  GA-PCOM
# 89258                                                                              Tzigane Inc
# 88637                                                                          Yale University
# 88046                                                        Brick Township board of education
# 85961                                                                       Classic Components
# 85818                                                                   Compensation Solutions
# 85781                                            Stanford University Libraries, LOCKSS Project
# 85675                                                                                   Macy's
# 84670                                            Diamond Management and Technology Consultants
# 84098                                                                                U.S. Bank
# 83979                                                                                       NC
# 83489                                                                     College Pro Painters
# 83185                                                                            Mana Products
# 74014                                                                           Apto Solutions
# 76629                                                                     Infinitely law group
# 81085                                                                       Town of Plainville
# 77792                                                                             Tanks Tavern
# 77757                                                                                      NaN
# 74505                                                                                      NaN
# 74323                                                                                Air Force
# 73582                                                                                      NaN
# 72998                                                               Halping hands company inc.
# 72176                                                                                      NaN
# 71623                                                                                      NaN
# 70686                                                                                Homemaker
# Total amount funded in policy code 1: 460296150                                            NaN
# Total amount funded in policy code 2: 0                                                    NaN
#
#                                                  ...  \
# id                                               ...
# 126065224                                        ...
# 126413271                                        ...
# 126176997                                        ...
# 126389018                                        ...
# 126406926                                        ...
# 125602675                                        ...
# 126154990                                        ...
# 126417318                                        ...
# 126410177                                        ...
# 125193750                                        ...
# 126338469                                        ...
# 126383696                                        ...
# 126309246                                        ...
# 126189493                                        ...
# 126419316                                        ...
# 125149625                                        ...
# 126309870                                        ...
# 126407653                                        ...
# 125907898                                        ...
# 125566359                                        ...
# 126273452                                        ...
# 126171880                                        ...
# 126365454                                        ...
# 126412424                                        ...
# 126193806                                        ...
# 126406609                                        ...
# 126414344                                        ...
# 125490256                                        ...
# 126165519                                        ...
# 126417216                                        ...
# ...                                              ...
# 91175                                            ...
# 91126                                            ...
# 91023                                            ...
# 90106                                            ...
# 89258                                            ...
# 88637                                            ...
# 88046                                            ...
# 85961                                            ...
# 85818                                            ...
# 85781                                            ...
# 85675                                            ...
# 84670                                            ...
# 84098                                            ...
# 83979                                            ...
# 83489                                            ...
# 83185                                            ...
# 74014                                            ...
# 76629                                            ...
# 81085                                            ...
# 77792                                            ...
# 77757                                            ...
# 74505                                            ...
# 74323                                            ...
# 73582                                            ...
# 72998                                            ...
# 72176                                            ...
# 71623                                            ...
# 70686                                            ...
# Total amount funded in policy code 1: 460296150  ...
# Total amount funded in policy code 2: 0          ...
#
#                                                 orig_projected_additional_accrued_interest  \
# id
# 126065224                                                                              NaN
# 126413271                                                                              NaN
# 126176997                                                                              NaN
# 126389018                                                                              NaN
# 126406926                                                                              NaN
# 125602675                                                                              NaN
# 126154990                                                                              NaN
# 126417318                                                                              NaN
# 126410177                                                                              NaN
# 125193750                                                                              NaN
# 126338469                                                                              NaN
# 126383696                                                                              NaN
# 126309246                                                                              NaN
# 126189493                                                                              NaN
# 126419316                                                                              NaN
# 125149625                                                                              NaN
# 126309870                                                                              NaN
# 126407653                                                                              NaN
# 125907898                                                                              NaN
# 125566359                                                                              NaN
# 126273452                                                                              NaN
# 126171880                                                                              NaN
# 126365454                                                                              NaN
# 126412424                                                                              NaN
# 126193806                                                                              NaN
# 126406609                                                                              NaN
# 126414344                                                                              NaN
# 125490256                                                                              NaN
# 126165519                                                                              NaN
# 126417216                                                                              NaN
# ...                                                                                    ...
# 91175                                                                                  NaN
# 91126                                                                                  NaN
# 91023                                                                                  NaN
# 90106                                                                                  NaN
# 89258                                                                                  NaN
# 88637                                                                                  NaN
# 88046                                                                                  NaN
# 85961                                                                                  NaN
# 85818                                                                                  NaN
# 85781                                                                                  NaN
# 85675                                                                                  NaN
# 84670                                                                                  NaN
# 84098                                                                                  NaN
# 83979                                                                                  NaN
# 83489                                                                                  NaN
# 83185                                                                                  NaN
# 74014                                                                                  NaN
# 76629                                                                                  NaN
# 81085                                                                                  NaN
# 77792                                                                                  NaN
# 77757                                                                                  NaN
# 74505                                                                                  NaN
# 74323                                                                                  NaN
# 73582                                                                                  NaN
# 72998                                                                                  NaN
# 72176                                                                                  NaN
# 71623                                                                                  NaN
# 70686                                                                                  NaN
# Total amount funded in policy code 1: 460296150                                        NaN
# Total amount funded in policy code 2: 0                                                NaN
#
#                                                 hardship_payoff_balance_amount  \
# id
# 126065224                                                                  NaN
# 126413271                                                                  NaN
# 126176997                                                                  NaN
# 126389018                                                                  NaN
# 126406926                                                                  NaN
# 125602675                                                                  NaN
# 126154990                                                                  NaN
# 126417318                                                                  NaN
# 126410177                                                                  NaN
# 125193750                                                                  NaN
# 126338469                                                                  NaN
# 126383696                                                                  NaN
# 126309246                                                                  NaN
# 126189493                                                                  NaN
# 126419316                                                                  NaN
# 125149625                                                                  NaN
# 126309870                                                                  NaN
# 126407653                                                                  NaN
# 125907898                                                                  NaN
# 125566359                                                                  NaN
# 126273452                                                                  NaN
# 126171880                                                                  NaN
# 126365454                                                                  NaN
# 126412424                                                                  NaN
# 126193806                                                                  NaN
# 126406609                                                                  NaN
# 126414344                                                                  NaN
# 125490256                                                                  NaN
# 126165519                                                                  NaN
# 126417216                                                                  NaN
# ...                                                                        ...
# 91175                                                                      NaN
# 91126                                                                      NaN
# 91023                                                                      NaN
# 90106                                                                      NaN
# 89258                                                                      NaN
# 88637                                                                      NaN
# 88046                                                                      NaN
# 85961                                                                      NaN
# 85818                                                                      NaN
# 85781                                                                      NaN
# 85675                                                                      NaN
# 84670                                                                      NaN
# 84098                                                                      NaN
# 83979                                                                      NaN
# 83489                                                                      NaN
# 83185                                                                      NaN
# 74014                                                                      NaN
# 76629                                                                      NaN
# 81085                                                                      NaN
# 77792                                                                      NaN
# 77757                                                                      NaN
# 74505                                                                      NaN
# 74323                                                                      NaN
# 73582                                                                      NaN
# 72998                                                                      NaN
# 72176                                                                      NaN
# 71623                                                                      NaN
# 70686                                                                      NaN
# Total amount funded in policy code 1: 460296150                            NaN
# Total amount funded in policy code 2: 0                                    NaN
#
#                                                  hardship_last_payment_amount  \
# id
# 126065224                                                                 NaN
# 126413271                                                                 NaN
# 126176997                                                                 NaN
# 126389018                                                                 NaN
# 126406926                                                                 NaN
# 125602675                                                                 NaN
# 126154990                                                                 NaN
# 126417318                                                                 NaN
# 126410177                                                                 NaN
# 125193750                                                                 NaN
# 126338469                                                                 NaN
# 126383696                                                                 NaN
# 126309246                                                                 NaN
# 126189493                                                                 NaN
# 126419316                                                                 NaN
# 125149625                                                                 NaN
# 126309870                                                                 NaN
# 126407653                                                                 NaN
# 125907898                                                                 NaN
# 125566359                                                                 NaN
# 126273452                                                                 NaN
# 126171880                                                                 NaN
# 126365454                                                                 NaN
# 126412424                                                                 NaN
# 126193806                                                                 NaN
# 126406609                                                                 NaN
# 126414344                                                                 NaN
# 125490256                                                                 NaN
# 126165519                                                                 NaN
# 126417216                                                                 NaN
# ...                                                                       ...
# 91175                                                                     NaN
# 91126                                                                     NaN
# 91023                                                                     NaN
# 90106                                                                     NaN
# 89258                                                                     NaN
# 88637                                                                     NaN
# 88046                                                                     NaN
# 85961                                                                     NaN
# 85818                                                                     NaN
# 85781                                                                     NaN
# 85675                                                                     NaN
# 84670                                                                     NaN
# 84098                                                                     NaN
# 83979                                                                     NaN
# 83489                                                                     NaN
# 83185                                                                     NaN
# 74014                                                                     NaN
# 76629                                                                     NaN
# 81085                                                                     NaN
# 77792                                                                     NaN
# 77757                                                                     NaN
# 74505                                                                     NaN
# 74323                                                                     NaN
# 73582                                                                     NaN
# 72998                                                                     NaN
# 72176                                                                     NaN
# 71623                                                                     NaN
# 70686                                                                     NaN
# Total amount funded in policy code 1: 460296150                           NaN
# Total amount funded in policy code 2: 0                                   NaN
#
#                                                 debt_settlement_flag  \
# id
# 126065224                                                          N
# 126413271                                                          N
# 126176997                                                          N
# 126389018                                                          N
# 126406926                                                          N
# 125602675                                                          N
# 126154990                                                          N
# 126417318                                                          N
# 126410177                                                          N
# 125193750                                                          N
# 126338469                                                          N
# 126383696                                                          N
# 126309246                                                          N
# 126189493                                                          N
# 126419316                                                          N
# 125149625                                                          N
# 126309870                                                          N
# 126407653                                                          N
# 125907898                                                          N
# 125566359                                                          N
# 126273452                                                          N
# 126171880                                                          N
# 126365454                                                          N
# 126412424                                                          N
# 126193806                                                          N
# 126406609                                                          N
# 126414344                                                          N
# 125490256                                                          N
# 126165519                                                          N
# 126417216                                                          N
# ...                                                              ...
# 91175                                                              N
# 91126                                                              N
# 91023                                                              N
# 90106                                                              N
# 89258                                                              N
# 88637                                                              N
# ...
# 125566359                                                   NaN
# 126273452                                                   NaN
# 126171880                                                   NaN
# 126365454                                                   NaN
# 126412424                                                   NaN
# 126193806                                                   NaN
# 126406609                                                   NaN
# 126414344                                                   NaN
# 125490256                                                   NaN
# 126165519                                                   NaN
# 126417216                                                   NaN
# ...                                                         ...
# 91175                                                       NaN
# 91126                                                       NaN
# 91023                                                       NaN
# 90106                                                       NaN
# 89258                                                       NaN
# 88637                                                       NaN
# 88046                                                       NaN
# 85961                                                       NaN
# 85818                                                       NaN
# 85781                                                       NaN
# 85675                                                       NaN
# 84670                                                       NaN
# 84098                                                       NaN
# 83979                                                       NaN
# 83489                                                       NaN
# 83185                                                       NaN
# 74014                                                       NaN
# 76629                                                       NaN
# 81085                                                       NaN
# 77792                                                       NaN
# 77757                                                       NaN
# 74505                                                       NaN
# 74323                                                       NaN
# 73582                                                       NaN
# 72998                                                       NaN
# 72176                                                       NaN
# 71623                                                       NaN
# 70686                                                       NaN
# Total amount funded in policy code 1: 460296150             NaN
# Total amount funded in policy code 2: 0                     NaN
#
#                                                 settlement_amount  \
# id
# 126065224                                                     NaN
# 126413271                                                     NaN
# 126176997                                                     NaN
# 126389018                                                     NaN
# 126406926                                                     NaN
# 125602675                                                     NaN
# 126154990                                                     NaN
# 126417318                                                     NaN
# 126410177                                                     NaN
# 125193750                                                     NaN
# 126338469                                                     NaN
# 126383696                                                     NaN
# 126309246                                                     NaN
# 126189493                                                     NaN
# 126419316                                                     NaN
# 125149625                                                     NaN
# 126309870                                                     NaN
# 126407653                                                     NaN
# 125907898                                                     NaN
# 125566359                                                     NaN
# 126273452                                                     NaN
# 126171880                                                     NaN
# 126365454                                                     NaN
# 126412424                                                     NaN
# 126193806                                                     NaN
# 126406609                                                     NaN
# 126414344                                                     NaN
# 125490256                                                     NaN
# 126165519                                                     NaN
# 126417216                                                     NaN
# ...                                                           ...
# 91175                                                         NaN
# 91126                                                         NaN
# 91023                                                         NaN
# 90106                                                         NaN
# 89258                                                         NaN
# 88637                                                         NaN
# 88046                                                         NaN
# 85961                                                         NaN
# 85818                                                         NaN
# 85781                                                         NaN
# 85675                                                         NaN
# 84670                                                         NaN
# 84098                                                         NaN
# 83979                                                         NaN
# 83489                                                         NaN
# 83185                                                         NaN
# 74014                                                         NaN
# 76629                                                         NaN
# 81085                                                         NaN
# 77792                                                         NaN
# 77757                                                         NaN
# 74505                                                         NaN
# 74323                                                         NaN
# 73582                                                         NaN
# 72998                                                         NaN
# 72176                                                         NaN
# 71623                                                         NaN
# 70686                                                         NaN
# Total amount funded in policy code 1: 460296150               NaN
# Total amount funded in policy code 2: 0                       NaN
#
#                                                 settlement_percentage  \
# id
# 126065224                                                         NaN
# 126413271                                                         NaN
# 126176997                                                         NaN
# 126389018                                                         NaN
# 126406926                                                         NaN
# 125602675                                                         NaN
# 126154990                                                         NaN
# 126417318                                                         NaN
# 126410177                                                         NaN
# 125193750                                                         NaN
# 126338469                                                         NaN
# 126383696                                                         NaN
# 126309246                                                         NaN
# 126189493                                                         NaN
# 126419316                                                         NaN
# 125149625                                                         NaN
# 126309870                                                         NaN
# 126407653                                                         NaN
# 125907898                                                         NaN
# 125566359                                                         NaN
# 126273452                                                         NaN
# 126171880                                                         NaN
# 126365454                                                         NaN
# 126412424                                                         NaN
# 126193806                                                         NaN
# 126406609                                                         NaN
# 126414344                                                         NaN
# 125490256                                                         NaN
# 126165519                                                         NaN
# 126417216                                                         NaN
# ...                                                               ...
# 91175                                                             NaN
# 91126                                                             NaN
# 91023                                                             NaN
# 90106                                                             NaN
# 89258                                                             NaN
# 88637                                                             NaN
# 88046                                                             NaN
# 85961                                                             NaN
# 85818                                                             NaN
# 85781                                                             NaN
# 85675                                                             NaN
# 84670                                                             NaN
# 84098                                                             NaN
# 83979                                                             NaN
# 83489                                                             NaN
# 83185                                                             NaN
# 74014                                                             NaN
# 76629                                                             NaN
# 81085                                                             NaN
# 77792                                                             NaN
# 77757                                                             NaN
# 74505                                                             NaN
# 74323                                                             NaN
# 73582                                                             NaN
# 72998                                                             NaN
# 72176                                                             NaN
# 71623                                                             NaN
# 70686                                                             NaN
# Total amount funded in policy code 1: 460296150                   NaN
# Total amount funded in policy code 2: 0                           NaN
#
#                                                 settlement_term
# id
# 126065224                                                   NaN
# 126413271                                                   NaN
# 126176997                                                   NaN
# 126389018                                                   NaN
# 126406926                                                   NaN
# 125602675                                                   NaN
# 126154990                                                   NaN
# 126417318                                                   NaN
# 126410177                                                   NaN
# 125193750                                                   NaN
# 126338469                                                   NaN
# 126383696                                                   NaN
# 126309246                                                   NaN
# 126189493                                                   NaN
# 126419316                                                   NaN
# 125149625                                                   NaN
# 126309870                                                   NaN
# 126407653                                                   NaN
# 125907898                                                   NaN
# 125566359                                                   NaN
# 126273452                                                   NaN
# 126171880                                                   NaN
# 126365454                                                   NaN
# 126412424                                                   NaN
# 126193806                                                   NaN
# 126406609                                                   NaN
# 126414344                                                   NaN
# 125490256                                                   NaN
# 126165519                                                   NaN
# 126417216                                                   NaN
# ...                                                         ...
# 91175                                                       NaN
# 91126                                                       NaN
# 91023                                                       NaN
# 90106                                                       NaN
# 89258                                                       NaN
# 88637                                                       NaN
# 88046                                                       NaN
# 85961                                                       NaN
# 85818                                                       NaN
# 85781                                                       NaN
# 85675                                                       NaN
# 84670                                                       NaN
# 84098                                                       NaN
# 83979                                                       NaN
# 83489                                                       NaN
# 83185                                                       NaN
# 74014                                                       NaN
# 76629                                                       NaN
# 81085                                                       NaN
# 77792                                                       NaN
# 77757                                                       NaN
# 74505                                                       NaN
# 74323                                                       NaN
# 73582                                                       NaN
# 72998                                                       NaN
# 72176                                                       NaN
# 71623                                                       NaN
# 70686                                                       NaN
# Total amount funded in policy code 1: 460296150             NaN
# Total amount funded in policy code 2: 0                     NaN
#
# [1765451 rows x 149 columns]

# %%
raw_lc_df['loan_status'].value_counts()
# Out:
# Fully Paid                                             1076208
# Current                                                 399465
# Charged Off                                             268335
# Late (31-120 days)                                       12138
# In Grace Period                                           3934
# Late (16-30 days)                                         2586
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     11
# Name: loan_status, dtype: int64

# %%
raw_lc_df.shape
# Out:
# (1765451, 149)

# %% [markdown]
# ## Data Cleaning

# %%
#FILTER OUT WHOSE STATUS IS NOT YET FINALIZED
raw_lc_df = raw_lc_df[raw_lc_df['loan_status'] != 'Current']
raw_lc_df = raw_lc_df[raw_lc_df['loan_status'] != 'Late (31-120 days)']
raw_lc_df = raw_lc_df[raw_lc_df['loan_status'] != 'Late (16-30 days)']
raw_lc_df = raw_lc_df[raw_lc_df['loan_status'] != 'In Grace Period']
raw_lc_df = raw_lc_df[raw_lc_df['loan_status'] != 'Does not meet the credit policy. Status:Fully Paid']
raw_lc_df = raw_lc_df[raw_lc_df['loan_status'] != 'Does not meet the credit policy. Status:Charged Off']

#BINARIZE CLASSES
raw_lc_df['loan_status'] = raw_lc_df['loan_status'].map({'Charged Off': 0, 'Default': 0, 'Fully Paid': 1})

# %%
raw_lc_df['earliest_cr_line'] = pd.to_timedelta(pd.to_datetime(raw_lc_df['earliest_cr_line'])).dt.days
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing datetime64-dtype data to TimedeltaIndex is deprecated, will raise a TypeError in a future version
#   """Entry point for launching an IPython kernel.

# %%
def parse_percentage(percentage):
    '''Change percentage features into floats'''
    if str(percentage) == 'nan': return math.nan
    new = percentage.replace('%', '')
    return float(new) / 100.0

raw_lc_df['revol_util'] = raw_lc_df['revol_util'].apply(parse_percentage)
raw_lc_df['int_rate'] = raw_lc_df['int_rate'].apply(parse_percentage)

# %%
raw_lc_df['zip_code'].nunique()
# Out:
# 945

# %%
#FILTER OUT COLUMNS THAT ARE OBVIOUSLY REDUNDANT OR UNHELPFUL
lc_df = raw_lc_df[['loan_amnt', 'funded_amnt','total_pymnt',
                'term', 'int_rate', 'installment',
                'emp_length', 'home_ownership', 'annual_inc',
                'verification_status', 'loan_status',
                'purpose', 'zip_code', 'addr_state', 'dti',
                'delinq_2yrs', 'earliest_cr_line', 'fico_range_low',
                'fico_range_high', 'inq_last_6mths', 'mths_since_last_delinq',
                'mths_since_last_record', 'open_acc', 'pub_rec', 'revol_bal',
                'revol_util', 'total_acc', 'out_prncp',
                'out_prncp_inv', 'last_fico_range_high', 'last_fico_range_low',
                'collections_12_mths_ex_med', 'mths_since_last_major_derog',
                'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
                'acc_now_delinq', 'tot_coll_amt',
                'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m',
                'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util',
                'open_rv_12m', 'open_rv_24m', 'all_util',
                'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
                'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
                'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
                'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
                'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
                'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
                'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
                'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
                'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats',
                'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m',
                'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'percent_bc_gt_75',
                'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim',
                'total_bal_ex_mort', 'total_bc_limit',
                'total_il_high_credit_limit','grade', 'collection_recovery_fee', 
                'total_rec_prncp', 'title', 'total_rec_int', 'total_rec_late_fee', 
                'sub_grade', 'debt_settlement_flag', 'emp_title','issue_d','last_pymnt_d']]

# %%
lc_df.shape
# Out:
# (1344579, 102)

# %%
lc_df = lc_df.dropna(axis=0, subset=['loan_amnt','inq_last_6mths'])

# %%
#CAST DATATYPES
dtype = {
      'loan_amnt': 'int64',
      'term': 'object',
      'int_rate': 'float64',
      'emp_length': 'object',
      'home_ownership': 'object',
      'annual_inc': 'float64',
      'verification_status': 'object',
      'loan_status': 'object',
      'purpose': 'object',
      'zip_code': 'object',
      'addr_state': 'object',
      'dti': 'float64',
      'delinq_2yrs': 'int64',
      'fico_range_low': 'int64',
      'fico_range_high': 'int64',
      'inq_last_6mths': 'int64',
      'open_acc': 'int64',
      'pub_rec': 'int64',
      'revol_bal': 'int64',
      'total_acc': 'int64',
      'application_type': 'object'
    }
lc_df = lc_df.astype(dtype=dtype)

# %%
lc_df.head().T
# Out:
# id                                126176997           125602675  \
# loan_amnt                             30000               13000
# funded_amnt                           30000               13000
# total_pymnt                         11758.3             13598.1
# term                              60 months           60 months
# int_rate                             0.3079              0.1505
# installment                          985.21              309.62
# emp_length                        10+ years           10+ years
# home_ownership                         RENT                RENT
# annual_inc                            40000               72000
# verification_status         Source Verified     Source Verified
# loan_status                               0                   1
# purpose                               other  debt_consolidation
# zip_code                              103xx               333xx
# addr_state                               NY                  FL
# dti                                   30.86               11.17
# delinq_2yrs                               1                   0
# earliest_cr_line                      12996               12965
# fico_range_low                          700                 705
# fico_range_high                         704                 709
# inq_last_6mths                            0                   0
# mths_since_last_delinq                    4                 NaN
# mths_since_last_record                  NaN                 NaN
# open_acc                                 11                   4
# pub_rec                                   0                   0
# revol_bal                             19754               12389
# revol_util                            0.303               0.774
# total_acc                                23                  13
# out_prncp                                 0                   0
# out_prncp_inv                             0                   0
# last_fico_range_high                    579                 764
# ...                                     ...                 ...
# num_bc_sats                               7                   2
# num_bc_tl                                12                   5
# num_il_tl                                 4                   5
# num_op_rev_tl                            10                   3
# num_rev_accts                            19                   8
# num_rev_tl_bal_gt_0                       7                   2
# num_sats                                 11                   4
# num_tl_120dpd_2m                          0                   0
# num_tl_30dpd                              0                   0
# num_tl_90g_dpd_24m                        0                   0
# num_tl_op_past_12m                        0                   0
# pct_tl_nvr_dlq                         95.7                 100
# percent_bc_gt_75                          0                  50
# pub_rec_bankruptcies                      0                   0
# tax_liens                                 0                   0
# tot_hi_cred_lim                       97743               34782
# total_bal_ex_mort                     46719               23941
# total_bc_limit                        44800               15000
# total_il_high_credit_limit            32543               18782
# grade                                     G                   C
# collection_recovery_fee                   0                   0
# total_rec_prncp                     2196.71               13000
# title                                 Other  Debt consolidation
# total_rec_int                       9463.05              598.13
# total_rec_late_fee                    98.52                   0
# sub_grade                                G1                  C4
# debt_settlement_flag                      N                   N
# emp_title                        Supervsir        Sales manager
# issue_d                            Dec-2017            Dec-2017
# last_pymnt_d                       Feb-2019            Apr-2018
#
# id                                   126417318            126407653  \
# loan_amnt                                15000                15750
# funded_amnt                              15000                15750
# total_pymnt                            16065.3                16392
# term                                 36 months            36 months
# int_rate                                0.1042               0.0735
# installment                             486.98               488.84
# emp_length                             3 years            10+ years
# home_ownership                            RENT                 RENT
# annual_inc                               55000                96500
# verification_status            Source Verified      Source Verified
# loan_status                                  1                    1
# purpose                     debt_consolidation   debt_consolidation
# zip_code                                 981xx                968xx
# addr_state                                  WA                   HI
# dti                                      17.48                12.22
# delinq_2yrs                                  0                    1
# earliest_cr_line                         14092                12173
# fico_range_low                             670                  705
# fico_range_high                            674                  709
# inq_last_6mths                               0                    0
# mths_since_last_delinq                     NaN                   10
# mths_since_last_record                     NaN                  NaN
# open_acc                                    28                    6
# pub_rec                                      0                    0
# revol_bal                                12673                 1868
# revol_util                               0.737                0.107
# total_acc                                   44                   17
# out_prncp                                    0                    0
# out_prncp_inv                                0                    0
# last_fico_range_high                       649                  714
# ...                                        ...                  ...
# num_bc_sats                                  2                    5
# num_bc_tl                                    2                    8
# num_il_tl                                   40                    6
# num_op_rev_tl                                4                    5
# num_rev_accts                                4                   11
# num_rev_tl_bal_gt_0                          3                    4
# num_sats                                    28                    6
# num_tl_120dpd_2m                             0                    0
# num_tl_30dpd                                 0                    0
# num_tl_90g_dpd_24m                           0                    1
# num_tl_op_past_12m                           0                    3
# pct_tl_nvr_dlq                             100                 88.2
# percent_bc_gt_75                            50                    0
# pub_rec_bankruptcies                         0                    0
# tax_liens                                    0                    0
# tot_hi_cred_lim                          69346               145171
# total_bal_ex_mort                        66150               128341
# total_bc_limit                           12200                17500
# total_il_high_credit_limit               52146               127671
# grade                                        B                    A
# collection_recovery_fee                      0                    0
# total_rec_prncp                          15000                15750
# title                       Debt consolidation   Debt consolidation
# total_rec_int                          1065.25               641.95
# total_rec_late_fee                           0                    0
# sub_grade                                   B3                   A4
# debt_settlement_flag                         N                    N
# emp_title                              Finance  Service Coordinator
# issue_d                               Dec-2017             Dec-2017
# last_pymnt_d                          Sep-2018             Sep-2018
#
# id                                        126273452
# loan_amnt                                     19800
# funded_amnt                                   19800
# total_pymnt                                 22271.9
# term                                      60 months
# int_rate                                     0.1505
# installment                                  471.57
# emp_length                                  3 years
# home_ownership                                 RENT
# annual_inc                                   108600
# verification_status                    Not Verified
# loan_status                                       1
# purpose                                 credit_card
# zip_code                                      021xx
# addr_state                                       MA
# dti                                           18.19
# delinq_2yrs                                       0
# earliest_cr_line                              14579
# fico_range_low                                  725
# fico_range_high                                 729
# inq_last_6mths                                    1
# mths_since_last_delinq                          NaN
# mths_since_last_record                          NaN
# open_acc                                         10
# pub_rec                                           0
# revol_bal                                      1458
# revol_util                                    0.037
# total_acc                                        14
# out_prncp                                         0
# out_prncp_inv                                     0
# last_fico_range_high                            714
# ...                                             ...
# num_bc_sats                                       6
# num_bc_tl                                         7
# num_il_tl                                         7
# num_op_rev_tl                                     6
# num_rev_accts                                     7
# num_rev_tl_bal_gt_0                               3
# num_sats                                         10
# num_tl_120dpd_2m                                  0
# num_tl_30dpd                                      0
# num_tl_90g_dpd_24m                                0
# num_tl_op_past_12m                                1
# pct_tl_nvr_dlq                                  100
# percent_bc_gt_75                                  0
# pub_rec_bankruptcies                              0
# tax_liens                                         0
# tot_hi_cred_lim                              143296
# total_bal_ex_mort                             90931
# total_bc_limit                                39500
# total_il_high_credit_limit                   103796
# grade                                             C
# collection_recovery_fee                           0
# total_rec_prncp                               19800
# title                       Credit card refinancing
# total_rec_int                               2471.93
# total_rec_late_fee                                0
# sub_grade                                        C4
# debt_settlement_flag                              N
# emp_title                                  engineer
# issue_d                                    Dec-2017
# last_pymnt_d                               Nov-2018
#
# [102 rows x 5 columns]

# %%
lc_df.columns[lc_df.isna().all()].tolist()
# Out:
# []

# %%
lc_df.shape
# Out:
# (1344553, 102)

# %%
#Change dtype
lc_df.loc[lc_df['emp_length'] == '< 1 year','emp_length'] = '0'
lc_df.loc[lc_df['emp_length'] == '10+ years', 'emp_length'] = '10'
lc_df['emp_length'] = lc_df['emp_length'].str[:1]
lc_df['emp_length'] = lc_df['emp_length'].astype(float)

# %%
lc_df['zip_code'].nunique()
# Out:
# 945

# %%
#Drop nulls in zip & emp_title
lc_df = lc_df[lc_df['zip_code'].notnull()]
lc_df = lc_df[lc_df['emp_title'].notnull()]

# %%
counts = lc_df['emp_title'].value_counts()
idx = counts[counts.lt(1600)].index

lc_df.loc[lc_df['emp_title'].isin(idx) == False, 'emp_title_2'] = lc_df['emp_title']
lc_df.loc[lc_df['emp_title'].isin(idx), 'emp_title_2'] = 'Other'

# %%
clean_lc_df = lc_df.copy()

# %%
clean_lc_df.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1260156 entries, 126176997 to 87023
# Data columns (total 103 columns):
# loan_amnt                         int64
# funded_amnt                       float64
# total_pymnt                       float64
# term                              object
# int_rate                          float64
# installment                       float64
# emp_length                        float64
# home_ownership                    object
# annual_inc                        float64
# verification_status               object
# loan_status                       object
# purpose                           object
# zip_code                          object
# addr_state                        object
# dti                               float64
# delinq_2yrs                       int64
# earliest_cr_line                  float64
# fico_range_low                    int64
# fico_range_high                   int64
# inq_last_6mths                    int64
# mths_since_last_delinq            float64
# mths_since_last_record            float64
# open_acc                          int64
# pub_rec                           int64
# revol_bal                         int64
# revol_util                        float64
# total_acc                         int64
# out_prncp                         float64
# out_prncp_inv                     float64
# last_fico_range_high              float64
# last_fico_range_low               float64
# collections_12_mths_ex_med        float64
# mths_since_last_major_derog       float64
# policy_code                       float64
# application_type                  object
# annual_inc_joint                  float64
# dti_joint                         float64
# acc_now_delinq                    float64
# tot_coll_amt                      float64
# tot_cur_bal                       float64
# open_acc_6m                       float64
# open_act_il                       float64
# open_il_12m                       float64
# open_il_24m                       float64
# mths_since_rcnt_il                float64
# total_bal_il                      float64
# il_util                           float64
# open_rv_12m                       float64
# open_rv_24m                       float64
# all_util                          float64
# total_rev_hi_lim                  float64
# inq_fi                            float64
# total_cu_tl                       float64
# inq_last_12m                      float64
# acc_open_past_24mths              float64
# avg_cur_bal                       float64
# bc_open_to_buy                    float64
# bc_util                           float64
# chargeoff_within_12_mths          float64
# delinq_amnt                       float64
# mo_sin_old_il_acct                float64
# mo_sin_old_rev_tl_op              float64
# mo_sin_rcnt_rev_tl_op             float64
# mo_sin_rcnt_tl                    float64
# mort_acc                          float64
# mths_since_recent_bc              float64
# mths_since_recent_bc_dlq          float64
# mths_since_recent_inq             float64
# mths_since_recent_revol_delinq    float64
# num_accts_ever_120_pd             float64
# num_actv_bc_tl                    float64
# num_actv_rev_tl                   float64
# num_bc_sats                       float64
# num_bc_tl                         float64
# num_il_tl                         float64
# num_op_rev_tl                     float64
# num_rev_accts                     float64
# num_rev_tl_bal_gt_0               float64
# num_sats                          float64
# num_tl_120dpd_2m                  float64
# num_tl_30dpd                      float64
# num_tl_90g_dpd_24m                float64
# num_tl_op_past_12m                float64
# pct_tl_nvr_dlq                    float64
# percent_bc_gt_75                  float64
# pub_rec_bankruptcies              float64
# tax_liens                         float64
# tot_hi_cred_lim                   float64
# total_bal_ex_mort                 float64
# total_bc_limit                    float64
# total_il_high_credit_limit        float64
# grade                             object
# collection_recovery_fee           float64
# total_rec_prncp                   float64
# title                             object
# total_rec_int                     float64
# total_rec_late_fee                float64
# sub_grade                         object
# debt_settlement_flag              object
# emp_title                         object
# issue_d                           object
# last_pymnt_d                      object
# emp_title_2                       object
# dtypes: float64(78), int64(9), object(16)
# memory usage: 999.9+ MB

# %%
clean_lc_df = clean_lc_df.dropna(subset=
                                 ['collections_12_mths_ex_med','chargeoff_within_12_mths','last_pymnt_d'],axis=0)

# %% [markdown]
# ### Feature Preprocessing

# %%
clean_lc_df
# Out:
#            loan_amnt  funded_amnt   total_pymnt        term  int_rate  \
# id
# 126176997      30000      30000.0  11758.280000   60 months    0.3079
# 125602675      13000      13000.0  13598.128415   60 months    0.1505
# 126417318      15000      15000.0  16065.250642   36 months    0.1042
# 126407653      15750      15750.0  16391.951100   36 months    0.0735
# 126273452      19800      19800.0  22271.932665   60 months    0.1505
# 126412424      10000      10000.0  10078.812117   36 months    0.0532
# 126413578      32600      32600.0  36636.103936   36 months    0.1199
# 126419328      10000      10000.0  10696.771384   36 months    0.0944
# 126383635      13000      13000.0  13569.535461   36 months    0.0993
# 126343082      10000      10000.0   3319.570000   36 months    0.0672
# 126367651      20000      20000.0   6606.500000   60 months    0.1806
# 126186267      20000      20000.0  22521.164503   60 months    0.2872
# 126379308      16000      16000.0  17919.210410   60 months    0.1262
# 126410270      25000      25000.0  25544.579768   60 months    0.3017
# 126414146      11000      11000.0  12079.472869   36 months    0.0993
# 126129726      20000      20000.0   3116.320000   60 months    0.1408
# 125755993       8000       8000.0   8756.272914   36 months    0.0944
# 125794785      35000      35000.0  37921.934358   36 months    0.1042
# 126418333       1200       1200.0   1289.972970   36 months    0.0735
# 126414116      20000      20000.0  20421.466321   36 months    0.0608
# 126406937       5000       5000.0   5136.906532   36 months    0.0608
# 126406059      12000      12000.0  12754.954233   36 months    0.0797
# 126307353      11200      11200.0   1973.560000   60 months    0.3065
# 126393995      10800      10800.0  10845.312000   60 months    0.0944
# 126413169       3200       3200.0   3460.072908   36 months    0.1199
# 126416189      13000      13000.0   4863.050000   60 months    0.2872
# 126281614       5000       5000.0   1810.310000   36 months    0.0944
# 126408759       2700       2700.0   2879.448475   36 months    0.0993
# 126417383      21000      21000.0  24168.518860   60 months    0.1505
# 126285300      40000      40000.0  41633.382830   36 months    0.0608
# ...              ...          ...           ...         ...       ...
# 126776          9500       9500.0  10727.304625   36 months    0.0807
# 131223         20000      20000.0  25188.823383   36 months    0.1565
# 130907          3775       3775.0   4191.717919   36 months    0.0743
# 130735         10250      10250.0  11444.365487   36 months    0.1438
# 130512          7250       7250.0   8192.665786   36 months    0.1059
# 129745         10000      10000.0  11663.558305   36 months    0.1028
# 128881          7000       7000.0   8570.680502   36 months    0.1249
# 128635          6500       6500.0   7648.052287   36 months    0.1028
# 127830          8000       8000.0   7294.680000   36 months    0.1217
# 127531         17000      17000.0  19555.185872   36 months    0.0933
# 126788          7500       7500.0   8104.154188   36 months    0.0933
# 126392         10000      10000.0  10435.303418   36 months    0.0807
# 126287         10000      10000.0  11068.421851   36 months    0.1154
# 126215          5000       5000.0   5459.636223   36 months    0.0775
# 126213          9500       9500.0  10727.304626   36 months    0.0807
# 125897          6625       6625.0   7174.090957   36 months    0.1122
# 125671         12125      12125.0  13819.081002   36 months    0.0870
# 124436          4800       4800.0   5675.572528   36 months    0.1122
# 123230          3175       3175.0    628.560000   36 months    0.1154
# 123228         20000      20000.0  12840.310000   36 months    0.0964
# 122718         18500      18500.0  20042.614226   36 months    0.1533
# 122637          4000       4000.0   4495.838507   36 months    0.0775
# 122404         12750      12750.0  13813.154376   36 months    0.1533
# 122070          5400       5400.0   6446.047047   36 months    0.1217
# 121824          3000       3000.0   3158.893661   36 months    0.0870
# 121530          3000       3000.0   3125.435781   36 months    0.0775
# 121426          3000       3000.0   3125.460949   36 months    0.0775
# 120525          4000       4000.0   4708.070922   36 months    0.1091
# 120374          2000       2000.0   2279.429900   36 months    0.0870
# 120215          4000       4000.0   4474.375860   36 months    0.0743
#
#            installment  emp_length home_ownership  annual_inc  \
# id
# 126176997       985.21         1.0           RENT     40000.0
# 125602675       309.62         1.0           RENT     72000.0
# 126417318       486.98         3.0           RENT     55000.0
# 126407653       488.84         1.0           RENT     96500.0
# 126273452       471.57         3.0           RENT    108600.0
# 126412424       301.15         1.0       MORTGAGE    100000.0
# 126413578      1082.64         0.0           RENT     55000.0
# 126419328       320.05         3.0           RENT     54000.0
# 126383635       419.05         1.0       MORTGAGE     85000.0
# 126343082       307.50         5.0       MORTGAGE     70000.0
# 126367651       508.53         5.0       MORTGAGE    110000.0
# 126186267       631.44         0.0           RENT     70000.0
# 126379308       360.95         7.0       MORTGAGE     55000.0
# 126410270       811.45         1.0       MORTGAGE    354000.0
# 126414146       354.58         9.0       MORTGAGE    110000.0
# 126129726       466.20         1.0       MORTGAGE     60000.0
# 125755993       256.04         1.0           RENT     84498.0
# 125794785      1136.27         1.0           RENT     55000.0
# 126418333        37.25         3.0           RENT     24000.0
# 126414116       609.17         5.0       MORTGAGE     50000.0
# 126406937       152.30         3.0            OWN    150000.0
# 126406059       375.88         0.0       MORTGAGE     65000.0
# 126307353       366.85         4.0       MORTGAGE     74460.0
# 126393995       226.51         5.0       MORTGAGE     75000.0
# 126413169       106.28         6.0       MORTGAGE     40000.0
# 126416189       410.44         1.0           RENT     50200.0
# 126281614       160.03         4.0           RENT     55000.0
# 126408759        87.04         3.0            OWN     55000.0
# 126417383       500.14         2.0       MORTGAGE     92000.0
# 126285300      1218.33         0.0       MORTGAGE    100000.0
# ...                ...         ...            ...         ...
# 126776          297.99         2.0            OWN     90000.0
# 131223          699.69         6.0           RENT     92000.0
# 130907          117.31         7.0       MORTGAGE    120000.0
# 130735          352.22         4.0           RENT     72000.0
# 130512          235.96         5.0       MORTGAGE     57000.0
# 129745          323.99         3.0           RENT    120000.0
# 128881          234.15         0.0           RENT     23000.0
# 128635          210.60         0.0            OWN     45000.0
# 127830          266.37         9.0       MORTGAGE     70000.0
# 127531          543.20         1.0           RENT     75000.0
# 126788          239.65         6.0       MORTGAGE     93000.0
# 126392          313.67         0.0       MORTGAGE    173000.0
# 126287          329.95         9.0       MORTGAGE    225000.0
# 126215          156.11         0.0           RENT     45000.0
# 126213          297.99         2.0            OWN     63000.0
# 125897          217.60         2.0       MORTGAGE     88000.0
# 125671          383.87         1.0       MORTGAGE    150000.0
# 124436          157.66         5.0           RENT     30000.0
# 123230          104.76         0.0            OWN     15000.0
# 123228          642.02         0.0           RENT     96000.0
# 122718          644.30         1.0           RENT     90000.0
# 122637          124.89         1.0            OWN     61800.0
# 122404          444.05         1.0           RENT     60000.0
# 122070          179.80         1.0       MORTGAGE     35000.0
# 121824           94.98         5.0       MORTGAGE     62000.0
# 121530           93.67         9.0            OWN     50000.0
# 121426           93.67         1.0            OWN    125000.0
# 120525          130.79         1.0           RENT     18000.0
# 120374           63.32         0.0           RENT     70000.0
# 120215          124.31         0.0           RENT     40000.0
#
#           verification_status  ... total_rec_prncp  \
# id                             ...
# 126176997     Source Verified  ...         2196.71
# 125602675     Source Verified  ...        13000.00
# 126417318     Source Verified  ...        15000.00
# 126407653     Source Verified  ...        15750.00
# 126273452        Not Verified  ...        19800.00
# 126412424     Source Verified  ...        10000.00
# 126413578     Source Verified  ...        32600.00
# 126419328        Not Verified  ...        10000.00
# 126383635     Source Verified  ...        13000.00
# 126343082            Verified  ...         1788.05
# 126367651     Source Verified  ...         1750.38
# 126186267     Source Verified  ...        20000.00
# 126379308     Source Verified  ...        16000.00
# 126410270            Verified  ...        25000.00
# 126414146        Not Verified  ...        11000.00
# 126129726            Verified  ...          231.53
# 125755993     Source Verified  ...         8000.00
# 125794785            Verified  ...        35000.00
# 126418333        Not Verified  ...         1200.00
# 126414116            Verified  ...        20000.00
# 126406937     Source Verified  ...         5000.00
# 126406059            Verified  ...        12000.00
# 126307353     Source Verified  ...           80.78
# 126393995     Source Verified  ...        10800.00
# 126413169        Not Verified  ...         3200.00
# 126416189     Source Verified  ...         1356.95
# 126281614     Source Verified  ...          992.58
# 126408759        Not Verified  ...         2700.00
# 126417383        Not Verified  ...        21000.00
# 126285300     Source Verified  ...        40000.00
# ...                       ...  ...             ...
# 126776           Not Verified  ...         9500.00
# 131223           Not Verified  ...        20000.00
# 130907           Not Verified  ...         3775.00
# 130735           Not Verified  ...        10250.00
# 130512           Not Verified  ...         7250.00
# 129745           Not Verified  ...        10000.00
# 128881           Not Verified  ...         7000.00
# 128635           Not Verified  ...         6500.00
# 127830           Not Verified  ...         5717.45
# 127531           Not Verified  ...        17000.00
# 126788           Not Verified  ...         7500.00
# 126392           Not Verified  ...        10000.00
# 126287           Not Verified  ...        10000.00
# 126215           Not Verified  ...         5000.00
# 126213           Not Verified  ...         9500.00
# 125897           Not Verified  ...         6625.00
# 125671           Not Verified  ...        12125.00
# 124436           Not Verified  ...         4800.00
# 123230           Not Verified  ...          455.95
# 123228           Not Verified  ...        10395.56
# 122718           Not Verified  ...        18500.00
# 122637           Not Verified  ...         4000.00
# 122404           Not Verified  ...        12750.00
# 122070           Not Verified  ...         5400.00
# 121824           Not Verified  ...         3000.00
# 121530           Not Verified  ...         3000.00
# 121426           Not Verified  ...         3000.00
# 120525           Not Verified  ...         4000.00
# 120374           Not Verified  ...         2000.00
# 120215           Not Verified  ...         4000.00
#
#                                              title total_rec_int  \
# id
# 126176997                                    Other       9463.05
# 125602675                       Debt consolidation        598.13
# 126417318                       Debt consolidation       1065.25
# 126407653                       Debt consolidation        641.95
# 126273452                  Credit card refinancing       2471.93
# 126412424                       Debt consolidation         78.81
# 126413578                              Home buying       4036.10
# 126419328                       Debt consolidation        696.77
# 126383635                       Debt consolidation        569.54
# 126343082                                    Other        371.08
# 126367651                       Debt consolidation       2267.69
# 126186267                           Major purchase       2521.16
# 126379308                       Debt consolidation       1919.21
# 126410270                       Debt consolidation        544.58
# 126414146                  Credit card refinancing       1079.47
# 126129726                         Home improvement        195.56
# 125755993                           Major purchase        756.27
# 125794785                                    Other       2921.93
# 126418333                       Debt consolidation         89.97
# 126414116                       Debt consolidation        421.47
# 126406937                       Debt consolidation        136.91
# 126406059                         Home improvement        754.95
# 126307353                         Medical expenses        238.39
# 126393995                         Medical expenses         45.31
# 126413169                                    Other        260.07
# 126416189                       Debt consolidation       3506.10
# 126281614                  Credit card refinancing        281.10
# 126408759                  Credit card refinancing        179.45
# 126417383                       Debt consolidation       3168.52
# 126285300                       Debt consolidation       1633.38
# ...                                            ...           ...
# 126776                          New Travel Trailer       1227.30
# 131223                             Working Capital       5188.82
# 130907                        Re-Lending to others        416.72
# 130735      Consolidate Car Loans and Credit Cards       1194.37
# 130512                                 Credit Card        942.67
# 129745         small business credit consolidation       1663.56
# 128881                                          RV       1540.68
# 128635                          Debt Consolidation       1088.05
# 127830                               Interest Rate       1474.29
# 127531                           Consolidate Bills       2555.19
# 126788               Home Improvement/ Investment         604.15
# 126392                                    Car Loan        435.30
# 126287                               Personal loan       1068.42
# 126215                      Transfer Personal Loan        459.64
# 126213                          New Travel Trailer       1227.30
# 125897                      Refinancing Mastercard        549.09
# 125671                      Get rid of these cards       1694.08
# 124436     Paying off higher interest credit cards        875.57
# 123230           Young Entrepreneur Needs Computer        172.24
# 123228                 I am expanding my business.       2442.88
# 122718             Paying off Credit Card balances       1542.61
# 122637                                   Apartment        495.84
# 122404              Consolidating Credit Card Debt       1063.15
# 122070                 Refinancing Prosper loan...       1046.05
# 121824                    Home improvement project        158.89
# 121530                                    Vacation        125.44
# 121426                       landscape improvement        125.46
# 120525                              Not so new car        708.07
# 120374                        Zach's Pre-Blis Loan        279.43
# 120215       Engineer seeks Environmental Training        474.38
#
#           total_rec_late_fee  sub_grade  debt_settlement_flag  \
# id
# 126176997              98.52         G1                     N
# 125602675               0.00         C4                     N
# 126417318               0.00         B3                     N
# 126407653               0.00         A4                     N
# 126273452               0.00         C4                     N
# 126412424               0.00         A1                     N
# 126413578               0.00         B5                     N
# 126419328               0.00         B1                     N
# 126383635               0.00         B2                     N
# 126343082              46.14         A3                     N
# 126367651               0.00         D2                     N
# 126186267               0.00         F1                     N
# 126379308               0.00         C1                     N
# 126410270               0.00         F3                     N
# 126414146               0.00         B2                     N
# 126129726               0.00         C3                     N
# 125755993               0.00         B1                     N
# 125794785               0.00         B3                     N
# 126418333               0.00         A4                     N
# 126414116               0.00         A2                     N
# 126406937               0.00         A2                     N
# 126406059               0.00         A5                     N
# 126307353               0.00         F4                     N
# 126393995               0.00         B1                     N
# 126413169               0.00         B5                     N
# 126416189               0.00         F1                     N
# 126281614               0.00         B1                     N
# 126408759               0.00         B2                     N
# 126417383               0.00         C4                     N
# 126285300               0.00         A2                     N
# ...                      ...        ...                   ...
# 126776                  0.00         A4                     N
# 131223                  0.00         F3                     N
# 130907                  0.00         A2                     N
# 130735                  0.00         E4                     N
# 130512                  0.00         C2                     N
# 129745                  0.00         C1                     N
# 128881                 30.00         D3                     N
# 128635                 60.00         C1                     N
# 127830                  0.00         D2                     N
# 127531                  0.00         B3                     N
# 126788                  0.00         B3                     N
# 126392                  0.00         A4                     N
# 126287                  0.00         C5                     N
# 126215                  0.00         A3                     N
# 126213                  0.00         A4                     N
# 125897                  0.00         C4                     N
# 125671                  0.00         B1                     N
# 124436                  0.00         C4                     N
# 123230                  0.00         C5                     N
# 123228                  0.00         B4                     N
# 122718                  0.00         F2                     N
# 122637                  0.00         A3                     N
# 122404                  0.00         F2                     N
# 122070                  0.00         D2                     N
# 121824                  0.00         B1                     N
# 121530                  0.00         A3                     N
# 121426                  0.00         A3                     N
# 120525                  0.00         C3                     N
# 120374                  0.00         B1                     N
# 120215                  0.00         A2                     N
#
#                                     emp_title   issue_d  last_pymnt_d  \
# id
# 126176997                          Supervsir   Dec-2017      Feb-2019
# 125602675                       Sales manager  Dec-2017      Apr-2018
# 126417318                             Finance  Dec-2017      Sep-2018
# 126407653                 Service Coordinator  Dec-2017      Sep-2018
# 126273452                            engineer  Dec-2017      Nov-2018
# 126412424                           Paralegal  Dec-2017      Feb-2018
# 126413578                  Admissions Advisor  Dec-2017      Mar-2019
# 126419328       Electro Mechanical Technician  Dec-2017      Oct-2018
# 126383635           Special Education Teacher  Dec-2017      Jul-2018
# 126343082                                  RN  Dec-2017      Sep-2018
# 126367651   N FL HCP Associate Vice President  Dec-2017      Sep-2018
# 126186267                                Lvn   Dec-2017      Jun-2018
# 126379308              Boss and only employee  Dec-2017      Dec-2018
# 126410270             chief operating officer  Dec-2017      Feb-2018
# 126414146                         Submissions  Dec-2017      Feb-2019
# 126129726                               Owner  Dec-2017      Feb-2018
# 125755993          Administrative Coordinator  Dec-2017      Feb-2019
# 125794785                            Room att  Dec-2017      Jan-2019
# 126418333                          Technician  Dec-2017      Apr-2019
# 126414116                                  vp  Dec-2017      May-2018
# 126406937                   Digital Marketing  Dec-2017      Aug-2018
# 126406059                    Network Engineer  Dec-2017      Dec-2018
# 126307353                          Field Tech  Dec-2017      Feb-2018
# 126393995           Assistant Bakery Manager   Dec-2017      Jan-2018
# 126413169                          Hairstlist  Dec-2017      Oct-2018
# 126416189                                aide  Dec-2017      Jan-2019
# 126281614                    Banquet Houseman  Dec-2017      Sep-2018
# 126408759                           Geologist  Dec-2017      Oct-2018
# 126417383        Program Manager, Marine Unit  Dec-2017      Jan-2019
# 126285300             Loss Mitigation Manager  Dec-2017      Oct-2018
# ...                                       ...       ...           ...
# 126776               Affinity Marketing Group  Oct-2007      Oct-2010
# 131223                       Chevy Chase Bank  Oct-2007      Oct-2010
# 130907                           SRA Benefits  Oct-2007      Aug-2010
# 130735              Cuban Medical Association  Oct-2007      Sep-2008
# 130512                                 Toyota  Oct-2007      May-2009
# 129745                            EYOND, Inc.  Sep-2007      Oct-2010
# 128881                              The Grove  Sep-2007      Nov-2010
# 128635                                 Cartus  Sep-2007      Oct-2010
# 127830                       Equality Florida  Sep-2007      Dec-2009
# 127531                                  NYCPD  Sep-2007      Sep-2010
# 126788              Suniland Associates, LTD.  Sep-2007      Sep-2008
# 126392                        Tideway Systems  Sep-2007      Apr-2008
# 126287               Affinity Marketing Group  Sep-2007      Oct-2008
# 126215          Fidelity Information Services  Sep-2007      May-2009
# 126213                       Holland & Knight  Sep-2007      Sep-2010
# 125897           Digiprotech Learning Systems  Sep-2007      Aug-2008
# 125671     Northwestern Mutual Life Insurance  Sep-2007      Sep-2010
# 124436         University of Nebraska-Lincoln  Sep-2007      Sep-2010
# 123230                       Tripolitan Films  Aug-2007      Mar-2008
# 123228                                   UDFI  Sep-2007      May-2009
# 122718                    Goldman Sachs & Co.  Aug-2007      Apr-2008
# 122637            Nestle Waters North America  Aug-2007      Sep-2010
# 122404            PerTrac Financial Solutions  Aug-2007      Apr-2008
# 122070               Citizens Financial Group  Aug-2007      Apr-2010
# 121824                            Fleurissima  Aug-2007      May-2008
# 121530                                Impress  Aug-2007      Apr-2008
# 121426                                Impress  Aug-2007      Apr-2008
# 120525                              Starbucks  Aug-2007      Aug-2010
# 120374          North Greenwich Financial LLC  Aug-2007      Aug-2010
# 120215         Community Environmental Center  Aug-2007      Aug-2010
#
#            emp_title_2
# id
# 126176997        Other
# 125602675        Other
# 126417318        Other
# 126407653        Other
# 126273452        Other
# 126412424    Paralegal
# 126413578        Other
# 126419328        Other
# 126383635        Other
# 126343082           RN
# 126367651        Other
# 126186267        Other
# 126379308        Other
# 126410270        Other
# 126414146        Other
# 126129726        Owner
# 125755993        Other
# 125794785        Other
# 126418333   Technician
# 126414116        Other
# 126406937        Other
# 126406059        Other
# 126307353        Other
# 126393995        Other
# 126413169        Other
# 126416189        Other
# 126281614        Other
# 126408759        Other
# 126417383        Other
# 126285300        Other
# ...                ...
# 126776           Other
# 131223           Other
# 130907           Other
# 130735           Other
# 130512           Other
# 129745           Other
# 128881           Other
# 128635           Other
# 127830           Other
# 127531           Other
# 126788           Other
# 126392           Other
# 126287           Other
# 126215           Other
# 126213           Other
# 125897           Other
# 125671           Other
# 124436           Other
# 123230           Other
# 123228           Other
# 122718           Other
# 122637           Other
# 122404           Other
# 122070           Other
# 121824           Other
# 121530           Other
# 121426           Other
# 120525           Other
# 120374           Other
# 120215           Other
#
# [1258501 rows x 103 columns]

# %% [markdown]
# ### TRAIN-TEST-SPLIT

# %%
X = clean_lc_df.drop(columns=['loan_status'])
y = clean_lc_df[['loan_status']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0,test_size=0.3)

# %% [markdown]
# #### Mean, Max, Zero Impute & Drops for Missing Values

# %%
#replace NaNs with column max, column means, or zeros where it makes sense to
nan_max_cols = [
    'mths_since_last_delinq',
    'mths_since_last_record',
    'mths_since_last_major_derog',
    'mths_since_rcnt_il',
    'mths_since_recent_bc',
    'mths_since_recent_bc_dlq',
    'mths_since_recent_inq',
    'mths_since_recent_revol_delinq',
    'mo_sin_old_il_acct',
    'mo_sin_old_rev_tl_op',
    'mo_sin_rcnt_rev_tl_op',
    'mo_sin_rcnt_tl',
]

nan_zero_cols = [
    'tot_coll_amt',
    'tot_cur_bal',
    'open_acc_6m',
    'open_act_il',
    'open_il_12m',
    'open_il_24m',
    'total_bal_il',
    'open_rv_12m',
    'open_rv_24m',
    'inq_fi',
    'inq_last_12m',
    'num_accts_ever_120_pd',
    'num_actv_bc_tl',
    'num_actv_rev_tl',
    'num_bc_sats',
    'num_bc_tl',
    'num_il_tl',
    'num_op_rev_tl',
    'num_rev_accts',
    'num_rev_tl_bal_gt_0',
    'num_sats',
    'num_tl_120dpd_2m',
    'num_tl_30dpd',
    'num_tl_90g_dpd_24m',
    'num_tl_op_past_12m',
    'mort_acc',
    'percent_bc_gt_75',
    'tot_hi_cred_lim',
    'total_bal_ex_mort',
    'total_bc_limit',
    'total_il_high_credit_limit',
    'bc_open_to_buy',
    'acc_open_past_24mths',
    'total_cu_tl',
    'total_rev_hi_lim',
    'emp_length',
    'pub_rec_bankruptcies',
    'tax_liens'
]

nan_mean_cols = [
    'dti',
    'annual_inc_joint',
    'dti_joint',
    'il_util',
    'all_util',
    'bc_util',
    'pct_tl_nvr_dlq',
    'avg_cur_bal',
    'revol_util',
]


for col in X_train:
    dt = X_train[col].dtype
    #FILL MISSING WITH MEAN from X_train, in both X_train & X_test
    if col in nan_mean_cols:
        X_train[col] = X_train[col].fillna(np.nanmean(X_train[col].values))
        X_test[col] = X_test[col].fillna(np.nanmean(X_train[col].values))
    #FILL MISSING WITH ZEROS from X_train, in both X_train & X_test
    if col in nan_zero_cols:
        X_train[col] = X_train[col].fillna(0.0)
        X_test[col] = X_test[col].fillna(0.0)
    #FILL MISSING WITH MAX from X_train, in both X_train & X_test
    if col in nan_max_cols:
        X_train[col] = X_train[col].fillna(np.nanmax(X_train[col].values) * 5)
        X_test[col] = X_test[col].fillna(np.nanmax(X_train[col].values) * 5)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_train.drop(columns=['title'],inplace=True)
X_test.drop(columns=['title'],inplace=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
null_columns=X_train.columns[X_train.isnull().any()]
X_train[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
null_columns=X_test.columns[X_test.isnull().any()]
X_test[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ### Categorical Variable One-Hot Encoding

# %%
print(clean_lc_df.shape) #103 columns
print(X_train.shape) #dropped title & loan_status (101 columns)
print(X_test.shape) #dropped title & loan_status (101 columns)
# Out:
# (1258501, 103)
# (880950, 101)
# (377551, 101)

# %%
X_train.to_pickle('X_train_pre_ohe_for_future_encoder.pkl') #for use in OHE encoder object on future data

# %% [markdown]
# ###### One-Hot Encode "term"

# %%
X_train['term'].value_counts()
# Out:
#  36 months    664098
#  60 months    216852
# Name: term, dtype: int64

# %%
#term
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['term']])
encoder.categories_
# Out:
# [array([' 36 months', ' 60 months'], dtype=object)]

# %%
ohe_term = pd.DataFrame(encoder.transform(X_train[['term']]).toarray(),
                        columns=encoder.get_feature_names(["term"]),index=X_train.index)
ohe_term_test = pd.DataFrame(encoder.transform(X_test[['term']]).toarray(),
                             columns=encoder.get_feature_names(["term"]),index=X_test.index)

ohe_term.shape
# Out:
# (880950, 2)

# %%
null_columns=ohe_term.columns[ohe_term.isnull().any()]
ohe_term[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ###### One-Hot Encode "home_ownership"

# %%
X_train['home_ownership'].value_counts()
# Out:
# MORTGAGE    437095
# RENT        354276
# OWN          89260
# ANY            176
# OTHER          111
# NONE            32
# Name: home_ownership, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['home_ownership']])
ohe_home_ownership = pd.DataFrame(encoder.transform(X_train[['home_ownership']]).toarray(),
                                  columns=encoder.get_feature_names(["home_ownership"]),index=X_train.index)
ohe_home_ownership_test = pd.DataFrame(encoder.transform(X_test[['home_ownership']]).toarray(),
                                       columns=encoder.get_feature_names(["home_ownership"]),index=X_test.index)

ohe_home_ownership.shape
# Out:
# (880950, 6)

# %%
null_columns=ohe_home_ownership.columns[ohe_home_ownership.isnull().any()]
ohe_home_ownership[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "purpose"

# %%
X_train['purpose'].value_counts()
# Out:
# debt_consolidation    515636
# credit_card           193927
# home_improvement       56020
# other                  49167
# major_purchase         18846
# small_business          9837
# medical                 9739
# car                     9350
# moving                  6120
# vacation                5753
# house                   4205
# wedding                 1530
# renewable_energy         593
# educational              227
# Name: purpose, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['purpose']])
ohe_purpose = pd.DataFrame(encoder.transform(X_train[['purpose']]).toarray(),
                           columns=encoder.get_feature_names(["purpose"]),index=X_train.index)
ohe_purpose_test = pd.DataFrame(encoder.transform(X_test[['purpose']]).toarray(),
                                columns=encoder.get_feature_names(["purpose"]),index=X_test.index)

ohe_purpose.shape
# Out:
# (880950, 14)

# %%
null_columns=ohe_purpose.columns[ohe_purpose.isnull().any()]
ohe_purpose[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "zip_code"

# %%
X_train['zip_code'].value_counts() #945 ZIP CODES
# Out:
# 945xx    9905
# 750xx    9713
# 112xx    9160
# 606xx    8265
# 300xx    8008
# 331xx    7590
# 070xx    7257
# 100xx    7116
# 770xx    7059
# 900xx    7014
# 330xx    6664
# 891xx    6649
# 917xx    6362
# 104xx    6219
# 117xx    6144
# 852xx    5642
# 921xx    5509
# 926xx    5359
# 913xx    5230
# 925xx    5130
# 334xx    4886
# 113xx    4623
# 601xx    4618
# 481xx    4589
# 604xx    4502
# 021xx    4490
# 853xx    4442
# 760xx    4415
# 600xx    4380
# 080xx    4362
#          ...
# 698xx       1
# 375xx       1
# 643xx       1
# 555xx       1
# 872xx       1
# 202xx       1
# 964xx       1
# 509xx       1
# 513xx       1
# 649xx       1
# 888xx       1
# 892xx       1
# 093xx       1
# 817xx       1
# 511xx       1
# 522xx       1
# 340xx       1
# 348xx       1
# 343xx       1
# 504xx       1
# 506xx       1
# 205xx       1
# 694xx       1
# 568xx       1
# 009xx       1
# 269xx       1
# 516xx       1
# 896xx       1
# 521xx       1
# 862xx       1
# Name: zip_code, Length: 930, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['zip_code']])
ohe_zip_code = pd.DataFrame(encoder.transform(X_train[['zip_code']]).toarray(),
                            columns=encoder.get_feature_names(["zip_code"]),index=X_train.index)
ohe_zip_code_test = pd.DataFrame(encoder.transform(X_test[['zip_code']]).toarray(),
                                 columns=encoder.get_feature_names(["zip_code"]),index=X_test.index)

ohe_zip_code.shape
# Out:
# (880950, 930)

# %%
null_columns=ohe_zip_code.columns[ohe_zip_code.isnull().any()]
ohe_zip_code[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "addr_state"

# %%
X_train['addr_state'].value_counts()
# Out:
# CA    128889
# TX     73175
# NY     72355
# FL     61290
# IL     34480
# NJ     32377
# PA     29962
# OH     28671
# GA     28397
# VA     25175
# NC     24495
# MI     22352
# MA     20772
# AZ     20728
# MD     20628
# CO     19477
# WA     19016
# MN     16005
# IN     14359
# MO     13931
# TN     13257
# CT     13159
# NV     12646
# WI     11745
# AL     10716
# OR     10555
# SC     10246
# LA     10210
# KY      8306
# OK      7984
# KS      7384
# UT      6527
# AR      6339
# NM      4746
# HI      4512
# NH      4283
# MS      4277
# RI      3883
# WV      3045
# MT      2471
# DE      2398
# NE      2337
# DC      2316
# AK      2097
# WY      1964
# SD      1817
# VT      1761
# ME      1299
# ND      1124
# ID      1006
# IA         6
# Name: addr_state, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['addr_state']])
ohe_addr_state = pd.DataFrame(encoder.transform(X_train[['addr_state']]).toarray(),
                              columns=encoder.get_feature_names(["addr_state"]),index=X_train.index)
ohe_addr_state_test = pd.DataFrame(encoder.transform(X_test[['addr_state']]).toarray(),
                                   columns=encoder.get_feature_names(["addr_state"]),index=X_test.index)

ohe_addr_state.shape
# Out:
# (880950, 51)

# %%
null_columns=ohe_addr_state.columns[ohe_addr_state.isnull().any()]
ohe_addr_state[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "application_type"

# %%
X_train['application_type'].value_counts()
# Out:
# Individual    868313
# Joint App      12637
# Name: application_type, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['application_type']])
ohe_application_type = pd.DataFrame(encoder.transform(X_train[['application_type']]).toarray(),
                                    columns=encoder.get_feature_names(["application_type"]),index=X_train.index)
ohe_application_type_test = pd.DataFrame(encoder.transform(X_test[['application_type']]).toarray(),
                                    columns=encoder.get_feature_names(["application_type"]),index=X_test.index)

ohe_application_type.shape
# Out:
# (880950, 2)

# %%
null_columns=ohe_application_type.columns[ohe_application_type.isnull().any()]
ohe_application_type[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "grade"

# %%
X_train['grade'].value_counts()
# Out:
# B    258330
# C    251178
# A    153700
# D    129383
# E     61236
# F     21026
# G      6097
# Name: grade, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['grade']])
ohe_grade = pd.DataFrame(encoder.transform(X_train[['grade']]).toarray(),
                         columns=encoder.get_feature_names(["grade"]),index=X_train.index)
ohe_grade_test = pd.DataFrame(encoder.transform(X_test[['grade']]).toarray(),
                              columns=encoder.get_feature_names(["grade"]),index=X_test.index)
ohe_grade.shape
# Out:
# (880950, 7)

# %%
null_columns=ohe_grade.columns[ohe_grade.isnull().any()]
ohe_grade[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "sub_grade"

# %%
X_train['sub_grade'].value_counts()
# Out:
# C1    56420
# B4    54578
# B3    54314
# B5    54225
# C2    52340
# C3    49256
# C4    48864
# B2    48538
# B1    46675
# C5    44298
# A5    41920
# A4    33796
# D1    33226
# A1    29711
# D2    28852
# D3    25301
# A3    24305
# A2    23968
# D4    22929
# D5    19075
# E1    15609
# E2    14035
# E3    12137
# E4    10361
# E5     9094
# F1     6469
# F2     4726
# F3     4019
# F4     3202
# F5     2610
# G1     1960
# G2     1465
# G3     1066
# G4      862
# G5      744
# Name: sub_grade, dtype: int64

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['sub_grade']])
ohe_sub_grade = pd.DataFrame(encoder.transform(X_train[['sub_grade']]).toarray(),
                             columns=encoder.get_feature_names(["sub_grade"]),index=X_train.index)
ohe_sub_grade_test = pd.DataFrame(encoder.transform(X_test[['sub_grade']]).toarray(),
                                  columns=encoder.get_feature_names(["sub_grade"]),index=X_test.index)

ohe_sub_grade.shape
# Out:
# (880950, 35)

# %%
null_columns=ohe_sub_grade.columns[ohe_sub_grade.isnull().any()]
ohe_sub_grade[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ##### One-Hot Encode "emp_title"

# %%
len(X_train['emp_title_2'].value_counts())
# Out:
# 50

# %%
encoder = OneHotEncoder(categories='auto',handle_unknown='ignore').fit(X_train[['emp_title_2']])
ohe_emp_title_2 = pd.DataFrame(encoder.transform(X_train[['emp_title_2']]).toarray(),
                               columns=encoder.get_feature_names(["emp_title_2"]),index=X_train.index)
ohe_emp_title_2_test = pd.DataFrame(encoder.transform(X_test[['emp_title_2']]).toarray(),
                                    columns=encoder.get_feature_names(["emp_title_2"]),index=X_test.index)

ohe_emp_title_2.shape
# Out:
# (880950, 50)

# %%
null_columns=ohe_emp_title_2.columns[ohe_emp_title_2.isnull().any()]
ohe_emp_title_2[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
X_train.shape
# Out:
# (880950, 101)

# %%
ohe_emp_title_2.shape
# Out:
# (880950, 50)

# %%
X_train.head()
# Out:
#           loan_amnt  funded_amnt   total_pymnt        term  int_rate  \
# id
# 40592931      20000      20000.0  24704.737119   60 months    0.1239
# 17715253      15000      15000.0  10780.580000   36 months    0.1299
# 64261034      16000      16000.0  18049.571386   36 months    0.0818
# 54353298      24000      24000.0  27124.598857   36 months    0.0818
# 8647714       24000      24000.0  26527.946309   36 months    0.0662
#
#           installment  emp_length home_ownership  annual_inc  \
# id
# 40592931       448.85         1.0       MORTGAGE     62000.0
# 17715253       505.34         1.0            OWN     55000.0
# 64261034       502.72         8.0       MORTGAGE     72000.0
# 54353298       754.07         1.0       MORTGAGE     70000.0
# 8647714        736.89         1.0       MORTGAGE    175000.0
#
#          verification_status  ... collection_recovery_fee total_rec_prncp  \
# id                            ...
# 40592931     Source Verified  ...                   0.000         20000.0
# 17715253            Verified  ...                 207.693          6863.3
# 64261034        Not Verified  ...                   0.000         16000.0
# 54353298     Source Verified  ...                   0.000         24000.0
# 8647714      Source Verified  ...                   0.000         24000.0
#
#          total_rec_int  total_rec_late_fee  sub_grade  debt_settlement_flag  \
# id
# 40592931       4704.74                0.00         C1                     N
# 17715253       2712.89               50.54         C1                     N
# 64261034       1974.15               75.42         B1                     N
# 54353298       3124.60                0.00         B1                     N
# 8647714        2527.95                0.00         A2                     N
#
#                          emp_title   issue_d  last_pymnt_d  emp_title_2
# id
# 40592931                    driver  Feb-2015      May-2017       driver
# 17715253                   Teacher  Jun-2014      May-2016      Teacher
# 64261034                  minister  Nov-2015      Jan-2019        Other
# 54353298  Southeast Retail Manager  Jul-2015      Jul-2018        Other
# 8647714                 IT Manager  Nov-2013      Nov-2016        Other
#
# [5 rows x 101 columns]

# %%
ohe_sub_grade.head()
# Out:
#           sub_grade_A1  sub_grade_A2  sub_grade_A3  sub_grade_A4  \
# id
# 40592931           0.0           0.0           0.0           0.0
# 17715253           0.0           0.0           0.0           0.0
# 64261034           0.0           0.0           0.0           0.0
# 54353298           0.0           0.0           0.0           0.0
# 8647714            0.0           1.0           0.0           0.0
#
#           sub_grade_A5  sub_grade_B1  sub_grade_B2  sub_grade_B3  \
# id
# 40592931           0.0           0.0           0.0           0.0
# 17715253           0.0           0.0           0.0           0.0
# 64261034           0.0           1.0           0.0           0.0
# 54353298           0.0           1.0           0.0           0.0
# 8647714            0.0           0.0           0.0           0.0
#
#           sub_grade_B4  sub_grade_B5  ...  sub_grade_F1  sub_grade_F2  \
# id                                    ...
# 40592931           0.0           0.0  ...           0.0           0.0
# 17715253           0.0           0.0  ...           0.0           0.0
# 64261034           0.0           0.0  ...           0.0           0.0
# 54353298           0.0           0.0  ...           0.0           0.0
# 8647714            0.0           0.0  ...           0.0           0.0
#
#           sub_grade_F3  sub_grade_F4  sub_grade_F5  sub_grade_G1  \
# id
# 40592931           0.0           0.0           0.0           0.0
# 17715253           0.0           0.0           0.0           0.0
# 64261034           0.0           0.0           0.0           0.0
# 54353298           0.0           0.0           0.0           0.0
# 8647714            0.0           0.0           0.0           0.0
#
#           sub_grade_G2  sub_grade_G3  sub_grade_G4  sub_grade_G5
# id
# 40592931           0.0           0.0           0.0           0.0
# 17715253           0.0           0.0           0.0           0.0
# 64261034           0.0           0.0           0.0           0.0
# 54353298           0.0           0.0           0.0           0.0
# 8647714            0.0           0.0           0.0           0.0
#
# [5 rows x 35 columns]

# %%
ohe_emp_title_2.head()
# Out:
#           emp_title_2_Account Executive  emp_title_2_Account Manager  \
# id
# 40592931                            0.0                          0.0
# 17715253                            0.0                          0.0
# 64261034                            0.0                          0.0
# 54353298                            0.0                          0.0
# 8647714                             0.0                          0.0
#
#           emp_title_2_Accountant  emp_title_2_Administrative Assistant  \
# id
# 40592931                     0.0                                   0.0
# 17715253                     0.0                                   0.0
# 64261034                     0.0                                   0.0
# 54353298                     0.0                                   0.0
# 8647714                      0.0                                   0.0
#
#           emp_title_2_Administrator  emp_title_2_Analyst  \
# id
# 40592931                        0.0                  0.0
# 17715253                        0.0                  0.0
# 64261034                        0.0                  0.0
# 54353298                        0.0                  0.0
# 8647714                         0.0                  0.0
#
#           emp_title_2_Assistant Manager  emp_title_2_Attorney  \
# id
# 40592931                            0.0                   0.0
# 17715253                            0.0                   0.0
# 64261034                            0.0                   0.0
# 54353298                            0.0                   0.0
# 8647714                             0.0                   0.0
#
#           emp_title_2_Branch Manager  emp_title_2_CEO  ...  \
# id                                                     ...
# 40592931                         0.0              0.0  ...
# 17715253                         0.0              0.0  ...
# 64261034                         0.0              0.0  ...
# 54353298                         0.0              0.0  ...
# 8647714                          0.0              0.0  ...
#
#           emp_title_2_Technician  emp_title_2_Truck Driver  \
# id
# 40592931                     0.0                       0.0
# 17715253                     0.0                       0.0
# 64261034                     0.0                       0.0
# 54353298                     0.0                       0.0
# 8647714                      0.0                       0.0
#
#           emp_title_2_Vice President  emp_title_2_driver  emp_title_2_manager  \
# id
# 40592931                         0.0                 1.0                  0.0
# 17715253                         0.0                 0.0                  0.0
# 64261034                         0.0                 0.0                  0.0
# 54353298                         0.0                 0.0                  0.0
# 8647714                          0.0                 0.0                  0.0
#
#           emp_title_2_owner  emp_title_2_sales  emp_title_2_supervisor  \
# id
# 40592931                0.0                0.0                     0.0
# 17715253                0.0                0.0                     0.0
# 64261034                0.0                0.0                     0.0
# 54353298                0.0                0.0                     0.0
# 8647714                 0.0                0.0                     0.0
#
#           emp_title_2_teacher  emp_title_2_truck driver
# id
# 40592931                  0.0                       0.0
# 17715253                  0.0                       0.0
# 64261034                  0.0                       0.0
# 54353298                  0.0                       0.0
# 8647714                   0.0                       0.0
#
# [5 rows x 50 columns]

# %% [markdown]
# #### One Hot Encode All Categorical Features

# %%
# encoder = OneHotEncoder(categories=['home_ownership','purpose','zip_code','sub_grade','emp_title_2'],
#                         handle_unknown='ignore').fit(X_train)
# ohe_all = pd.DataFrame(encoder.transform(X_train).toarray(),
#                        columns=encoder.get_feature_names(
#                            ['home_ownership','purpose','zip_code','sub_grade','emp_title_2']))
# ohe_all_test = pd.DataFrame(encoder.transform(X_train).toarray(),
#                             columns=encoder.get_feature_names(
#                                 ['home_ownership','purpose','zip_code','sub_grade','emp_title_2']))

# %% [markdown]
# ### Join X_train with new One-Hot-Encoded TRAIN DataFrames
# ##### & Join X_test with new One-Hot Encoded TEST DataFrames
# - X_train + ohe_home_ownership + ohe_purpose + ohe_zip_code + ohe_application_type + ohe_sub_grade(more granular than ohe_grade) + ohe_emp_title_2
# - I'm opting for Zip Code (944 cols) instead of State (50 cols - D.C. counts) in the first model under the hypothesis that the more granular location-based variable (zip) will reveal a more meaningful relationship than the broader borders of State

# %%
#Individual DF shapes
print(X_train.shape)
print(ohe_home_ownership.shape)
print(ohe_purpose.shape)
print(ohe_zip_code.shape)
print(ohe_application_type.shape)
print(ohe_sub_grade.shape)
print(ohe_emp_title_2.shape)
# Out:
# (880950, 101)
# (880950, 6)
# (880950, 14)
# (880950, 930)
# (880950, 2)
# (880950, 35)
# (880950, 50)

# %%
type(ohe_emp_title_2)
# Out:
# pandas.core.frame.DataFrame

# %%
#Future Shape
print(X_train.shape[1]+ohe_home_ownership.shape[1]+ohe_purpose.shape[1]+
      ohe_zip_code.shape[1]+ohe_sub_grade.shape[1]+
     ohe_emp_title_2.shape[1])
# Out:
# 1136

# %%
#concat_test_dfs = [X_train, ohe_home_ownership, ohe_purpose, ohe_zip_code,
#                   ohe_application_type, ohe_sub_grade, ohe_emp_title_2]
X_train_comb = X_train
X_train_comb = pd.concat([X_train_comb.drop("home_ownership", axis=1), ohe_home_ownership], axis=1)

# %%
X_train_comb = pd.concat([X_train_comb.drop("purpose", axis=1), ohe_purpose], axis=1)

# %%
X_train_comb = pd.concat([X_train_comb.drop("zip_code", axis=1), ohe_zip_code], axis=1)

# %%
X_train_comb = pd.concat([X_train_comb.drop("application_type", axis=1), ohe_application_type], axis=1)

# %%
X_train_comb = pd.concat([X_train_comb.drop("sub_grade", axis=1), ohe_sub_grade], axis=1)

# %%
X_train_comb = pd.concat([X_train_comb.drop("emp_title_2", axis=1), ohe_emp_title_2], axis=1)

# %%
null_columns=X_train_comb.columns[X_train_comb.isnull().any()]
X_train_comb[null_columns].isnull().sum()

# %%
X_train_comb.shape
# Out:
# (880950, 1132)

# %%
#concat_test_dfs = [X_test, ohe_home_ownership_test, ohe_purpose_test, ohe_zip_code_test,
#                   ohe_application_type_test, ohe_sub_grade_test, ohe_emp_title_2_test]
X_test_comb = X_test
X_test_comb = pd.concat([X_test_comb.drop("home_ownership", axis=1), ohe_home_ownership_test], axis=1)

# %%
X_test_comb = pd.concat([X_test_comb.drop("purpose", axis=1), ohe_purpose_test], axis=1)

# %%
X_test_comb = pd.concat([X_test_comb.drop("zip_code", axis=1), ohe_zip_code_test], axis=1)

# %%
X_test_comb = pd.concat([X_test_comb.drop("application_type", axis=1), ohe_application_type_test], axis=1)

# %%
X_test_comb = pd.concat([X_test_comb.drop("sub_grade", axis=1), ohe_sub_grade_test], axis=1)

# %%
X_test_comb = pd.concat([X_test_comb.drop("emp_title_2", axis=1), ohe_emp_title_2_test], axis=1)

# %%
null_columns=X_test_comb.columns[X_test_comb.isnull().any()]
X_test_comb[null_columns].isnull().sum()

# %% [markdown]
# ### Reinstate X_train & X_test

# %%
X_test = X_test_comb

# %%
X_train = X_train_comb

# %% [markdown]
# ### Save Each Set to a .TSV File

# %%
#X_train.to_csv('X_train.tsv', sep='\t',chunksize=1000, compression='zip')

# %%
#X_test.to_csv('X_test.tsv', sep='\t',chunksize=1000, compression='zip')

# %%
#y_train.to_csv('y_train.tsv', sep='\t',chunksize=1000, compression='zip')

# %%
#y_test.to_csv('y_test.tsv', sep='\t',chunksize=1000, compression='zip')

# %% [markdown]
# ### Save Each Dataframe to a .PKL file

# %%
X_train.to_pickle('X_train.pkl')

# %%
X_test.to_pickle('X_test.pkl')

# %%
y_train.to_pickle('y_train.pkl')

# %%
y_test.to_pickle('y_test.pkl')

# %%
X_train.shape
# Out:
# (880950, 1132)

# %%
X_test.shape
# Out:
# (377551, 1132)

# %%
y_train.shape
# Out:
# (880950, 1)

# %%
y_test.shape
# Out:
# (377551, 1)
