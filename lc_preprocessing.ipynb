# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import math
import seaborn as sns
import random

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Randomly Sample 10% of Train & Test sets due to large file size

# %%
filename = "X_train.tsv"
n = sum(1 for line in open(filename)) - 1 #number of records in file (excludes header)
s = 114663 #desired sample size
skip = sorted(random.sample(range(1,n+1),n-s)) #the 0-indexed header will not be included in the skip list
X_train_10pcnt = pd.read_csv(filename, skiprows=skip, sep='\t',index_col=0)

#X_test
filename = "X_test.tsv"
s = 64334
X_test_10pcnt = pd.read_csv(filename, skiprows=skip, sep='\t',index_col=0)

#y_train
filename = "y_train.tsv"
s = 88036
y_train_10pcnt = pd.read_csv(filename, skiprows=skip, sep='\t',index_col=0)

#y_test
filename = "y_test.tsv"
s = 37882
y_test_10pcnt = pd.read_csv(filename, skiprows=skip, sep='\t',index_col=0)

# %%
print(X_train_10pcnt.shape)
print(X_test_10pcnt.shape)
print(y_train_10pcnt.shape)
print(y_test_10pcnt.shape)
# Out:
# (114663, 1133)
# (63979, 1133)
# (88003, 1)
# (37693, 1)

# %%
X_train_10pcnt.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114663 entries, 12 to 1260151
# Data columns (total 1133 columns):
# loan_amnt                               float64
# funded_amnt                             float64
# term                                    object
# int_rate                                float64
# installment                             float64
# emp_length                              float64
# home_ownership                          object
# annual_inc                              float64
# verification_status                     object
# purpose                                 object
# zip_code                                object
# addr_state                              object
# dti                                     float64
# delinq_2yrs                             float64
# earliest_cr_line                        float64
# fico_range_low                          float64
# fico_range_high                         float64
# inq_last_6mths                          float64
# mths_since_last_delinq                  float64
# mths_since_last_record                  float64
# open_acc                                float64
# pub_rec                                 float64
# revol_bal                               float64
# revol_util                              float64
# total_acc                               float64
# out_prncp                               float64
# out_prncp_inv                           float64
# last_fico_range_high                    float64
# last_fico_range_low                     float64
# collections_12_mths_ex_med              float64
# mths_since_last_major_derog             float64
# policy_code                             float64
# application_type                        object
# annual_inc_joint                        float64
# dti_joint                               float64
# acc_now_delinq                          float64
# tot_coll_amt                            float64
# tot_cur_bal                             float64
# open_acc_6m                             float64
# open_act_il                             float64
# open_il_12m                             float64
# open_il_24m                             float64
# mths_since_rcnt_il                      float64
# total_bal_il                            float64
# il_util                                 float64
# open_rv_12m                             float64
# open_rv_24m                             float64
# all_util                                float64
# total_rev_hi_lim                        float64
# inq_fi                                  float64
# total_cu_tl                             float64
# inq_last_12m                            float64
# acc_open_past_24mths                    float64
# avg_cur_bal                             float64
# bc_open_to_buy                          float64
# bc_util                                 float64
# chargeoff_within_12_mths                float64
# delinq_amnt                             float64
# mo_sin_old_il_acct                      float64
# mo_sin_old_rev_tl_op                    float64
# mo_sin_rcnt_rev_tl_op                   float64
# mo_sin_rcnt_tl                          float64
# mort_acc                                float64
# mths_since_recent_bc                    float64
# mths_since_recent_bc_dlq                float64
# mths_since_recent_inq                   float64
# mths_since_recent_revol_delinq          float64
# num_accts_ever_120_pd                   float64
# num_actv_bc_tl                          float64
# num_actv_rev_tl                         float64
# num_bc_sats                             float64
# num_bc_tl                               float64
# num_il_tl                               float64
# num_op_rev_tl                           float64
# num_rev_accts                           float64
# num_rev_tl_bal_gt_0                     float64
# num_sats                                float64
# num_tl_120dpd_2m                        float64
# num_tl_30dpd                            float64
# num_tl_90g_dpd_24m                      float64
# num_tl_op_past_12m                      float64
# pct_tl_nvr_dlq                          float64
# percent_bc_gt_75                        float64
# pub_rec_bankruptcies                    float64
# tax_liens                               float64
# tot_hi_cred_lim                         float64
# total_bal_ex_mort                       float64
# total_bc_limit                          float64
# total_il_high_credit_limit              float64
# grade                                   object
# collection_recovery_fee                 float64
# total_rec_prncp                         float64
# title                                   object
# total_rec_int                           float64
# total_rec_late_fee                      float64
# sub_grade                               object
# debt_settlement_flag                    object
# emp_title                               object
# issue_d                                 object
# last_pymnt_d                            object
# emp_title_2                             object
# home_ownership_MORTGAGE                 float64
# home_ownership_NONE                     float64
# home_ownership_OTHER                    float64
# home_ownership_OWN                      float64
# home_ownership_RENT                     float64
# purpose_credit_card                     float64
# purpose_debt_consolidation              float64
# purpose_educational                     float64
# purpose_home_improvement                float64
# purpose_house                           float64
# purpose_major_purchase                  float64
# purpose_medical                         float64
# purpose_moving                          float64
# purpose_other                           float64
# purpose_renewable_energy                float64
# purpose_small_business                  float64
# purpose_vacation                        float64
# purpose_wedding                         float64
# zip_code_007xx                          float64
# zip_code_008xx                          float64
# zip_code_009xx                          float64
# zip_code_010xx                          float64
# zip_code_011xx                          float64
# zip_code_012xx                          float64
# zip_code_013xx                          float64
# zip_code_014xx                          float64
# zip_code_015xx                          float64
# zip_code_016xx                          float64
# zip_code_017xx                          float64
# zip_code_018xx                          float64
# zip_code_019xx                          float64
# zip_code_020xx                          float64
# zip_code_021xx                          float64
# zip_code_022xx                          float64
# zip_code_023xx                          float64
# zip_code_024xx                          float64
# zip_code_025xx                          float64
# zip_code_026xx                          float64
# zip_code_027xx                          float64
# zip_code_028xx                          float64
# zip_code_029xx                          float64
# zip_code_030xx                          float64
# zip_code_031xx                          float64
# zip_code_032xx                          float64
# zip_code_033xx                          float64
# zip_code_034xx                          float64
# zip_code_035xx                          float64
# zip_code_036xx                          float64
# zip_code_037xx                          float64
# zip_code_038xx                          float64
# zip_code_039xx                          float64
# zip_code_040xx                          float64
# zip_code_041xx                          float64
# zip_code_042xx                          float64
# zip_code_043xx                          float64
# zip_code_044xx                          float64
# zip_code_045xx                          float64
# zip_code_046xx                          float64
# zip_code_047xx                          float64
# zip_code_048xx                          float64
# zip_code_049xx                          float64
# zip_code_050xx                          float64
# zip_code_051xx                          float64
# zip_code_052xx                          float64
# zip_code_053xx                          float64
# zip_code_054xx                          float64
# zip_code_056xx                          float64
# zip_code_057xx                          float64
# zip_code_058xx                          float64
# zip_code_059xx                          float64
# zip_code_060xx                          float64
# zip_code_061xx                          float64
# zip_code_062xx                          float64
# zip_code_063xx                          float64
# zip_code_064xx                          float64
# zip_code_065xx                          float64
# zip_code_066xx                          float64
# zip_code_067xx                          float64
# zip_code_068xx                          float64
# zip_code_069xx                          float64
# zip_code_070xx                          float64
# zip_code_071xx                          float64
# zip_code_072xx                          float64
# zip_code_073xx                          float64
# zip_code_074xx                          float64
# zip_code_075xx                          float64
# zip_code_076xx                          float64
# zip_code_077xx                          float64
# zip_code_078xx                          float64
# zip_code_079xx                          float64
# zip_code_080xx                          float64
# zip_code_081xx                          float64
# zip_code_082xx                          float64
# zip_code_083xx                          float64
# zip_code_084xx                          float64
# zip_code_085xx                          float64
# zip_code_086xx                          float64
# zip_code_087xx                          float64
# zip_code_088xx                          float64
# zip_code_089xx                          float64
# zip_code_090xx                          float64
# zip_code_091xx                          float64
# zip_code_092xx                          float64
# zip_code_093xx                          float64
# zip_code_094xx                          float64
# zip_code_096xx                          float64
# zip_code_097xx                          float64
# zip_code_098xx                          float64
# zip_code_100xx                          float64
# zip_code_101xx                          float64
# zip_code_102xx                          float64
# zip_code_103xx                          float64
# zip_code_104xx                          float64
# zip_code_105xx                          float64
# zip_code_106xx                          float64
# zip_code_107xx                          float64
# zip_code_108xx                          float64
# zip_code_109xx                          float64
# zip_code_110xx                          float64
# zip_code_111xx                          float64
# zip_code_112xx                          float64
# zip_code_113xx                          float64
# zip_code_114xx                          float64
# zip_code_115xx                          float64
# zip_code_116xx                          float64
# zip_code_117xx                          float64
# zip_code_118xx                          float64
# zip_code_119xx                          float64
# zip_code_120xx                          float64
# zip_code_121xx                          float64
# zip_code_122xx                          float64
# zip_code_123xx                          float64
# zip_code_124xx                          float64
# zip_code_125xx                          float64
# zip_code_126xx                          float64
# zip_code_127xx                          float64
# zip_code_128xx                          float64
# zip_code_129xx                          float64
# zip_code_130xx                          float64
# zip_code_131xx                          float64
# zip_code_132xx                          float64
# zip_code_133xx                          float64
# zip_code_134xx                          float64
# zip_code_135xx                          float64
# zip_code_136xx                          float64
# zip_code_137xx                          float64
# zip_code_138xx                          float64
# zip_code_139xx                          float64
# zip_code_140xx                          float64
# zip_code_141xx                          float64
# zip_code_142xx                          float64
# zip_code_143xx                          float64
# zip_code_144xx                          float64
# zip_code_145xx                          float64
# zip_code_146xx                          float64
# zip_code_147xx                          float64
# zip_code_148xx                          float64
# zip_code_149xx                          float64
# zip_code_150xx                          float64
# zip_code_151xx                          float64
# zip_code_152xx                          float64
# zip_code_153xx                          float64
# zip_code_154xx                          float64
# zip_code_155xx                          float64
# zip_code_156xx                          float64
# zip_code_157xx                          float64
# zip_code_158xx                          float64
# zip_code_159xx                          float64
# zip_code_160xx                          float64
# zip_code_161xx                          float64
# zip_code_162xx                          float64
# zip_code_163xx                          float64
# zip_code_164xx                          float64
# zip_code_165xx                          float64
# zip_code_166xx                          float64
# zip_code_167xx                          float64
# zip_code_168xx                          float64
# zip_code_169xx                          float64
# zip_code_170xx                          float64
# zip_code_171xx                          float64
# zip_code_172xx                          float64
# zip_code_173xx                          float64
# zip_code_174xx                          float64
# zip_code_175xx                          float64
# zip_code_176xx                          float64
# zip_code_177xx                          float64
# zip_code_178xx                          float64
# zip_code_179xx                          float64
# zip_code_180xx                          float64
# zip_code_181xx                          float64
# zip_code_182xx                          float64
# zip_code_183xx                          float64
# zip_code_184xx                          float64
# zip_code_185xx                          float64
# zip_code_186xx                          float64
# zip_code_187xx                          float64
# zip_code_188xx                          float64
# zip_code_189xx                          float64
# zip_code_190xx                          float64
# zip_code_191xx                          float64
# zip_code_193xx                          float64
# zip_code_194xx                          float64
# zip_code_195xx                          float64
# zip_code_196xx                          float64
# zip_code_197xx                          float64
# zip_code_198xx                          float64
# zip_code_199xx                          float64
# zip_code_200xx                          float64
# zip_code_201xx                          float64
# zip_code_202xx                          float64
# zip_code_203xx                          float64
# zip_code_204xx                          float64
# zip_code_205xx                          float64
# zip_code_206xx                          float64
# zip_code_207xx                          float64
# zip_code_208xx                          float64
# zip_code_209xx                          float64
# zip_code_210xx                          float64
# zip_code_211xx                          float64
# zip_code_212xx                          float64
# zip_code_214xx                          float64
# zip_code_215xx                          float64
# zip_code_216xx                          float64
# zip_code_217xx                          float64
# zip_code_218xx                          float64
# zip_code_219xx                          float64
# zip_code_220xx                          float64
# zip_code_221xx                          float64
# zip_code_222xx                          float64
# zip_code_223xx                          float64
# zip_code_224xx                          float64
# zip_code_225xx                          float64
# zip_code_226xx                          float64
# zip_code_227xx                          float64
# zip_code_228xx                          float64
# zip_code_229xx                          float64
# zip_code_230xx                          float64
# zip_code_231xx                          float64
# zip_code_232xx                          float64
# zip_code_233xx                          float64
# zip_code_234xx                          float64
# zip_code_235xx                          float64
# zip_code_236xx                          float64
# zip_code_237xx                          float64
# zip_code_238xx                          float64
# zip_code_239xx                          float64
# zip_code_240xx                          float64
# zip_code_241xx                          float64
# zip_code_242xx                          float64
# zip_code_243xx                          float64
# zip_code_244xx                          float64
# zip_code_245xx                          float64
# zip_code_246xx                          float64
# zip_code_247xx                          float64
# zip_code_248xx                          float64
# zip_code_249xx                          float64
# zip_code_250xx                          float64
# zip_code_251xx                          float64
# zip_code_252xx                          float64
# zip_code_253xx                          float64
# zip_code_254xx                          float64
# zip_code_255xx                          float64
# zip_code_256xx                          float64
# zip_code_257xx                          float64
# zip_code_258xx                          float64
# zip_code_259xx                          float64
# zip_code_260xx                          float64
# zip_code_261xx                          float64
# zip_code_262xx                          float64
# zip_code_263xx                          float64
# zip_code_264xx                          float64
# zip_code_265xx                          float64
# zip_code_266xx                          float64
# zip_code_267xx                          float64
# zip_code_268xx                          float64
# zip_code_269xx                          float64
# zip_code_270xx                          float64
# zip_code_271xx                          float64
# zip_code_272xx                          float64
# zip_code_273xx                          float64
# zip_code_274xx                          float64
# zip_code_275xx                          float64
# zip_code_276xx                          float64
# zip_code_277xx                          float64
# zip_code_278xx                          float64
# zip_code_279xx                          float64
# zip_code_280xx                          float64
# zip_code_281xx                          float64
# zip_code_282xx                          float64
# zip_code_283xx                          float64
# zip_code_284xx                          float64
# zip_code_285xx                          float64
# zip_code_286xx                          float64
# zip_code_287xx                          float64
# zip_code_288xx                          float64
# zip_code_289xx                          float64
# zip_code_290xx                          float64
# zip_code_291xx                          float64
# zip_code_292xx                          float64
# zip_code_293xx                          float64
# zip_code_294xx                          float64
# zip_code_295xx                          float64
# zip_code_296xx                          float64
# zip_code_297xx                          float64
# zip_code_298xx                          float64
# zip_code_299xx                          float64
# zip_code_300xx                          float64
# zip_code_301xx                          float64
# zip_code_302xx                          float64
# zip_code_303xx                          float64
# zip_code_304xx                          float64
# zip_code_305xx                          float64
# zip_code_306xx                          float64
# zip_code_307xx                          float64
# zip_code_308xx                          float64
# zip_code_309xx                          float64
# zip_code_310xx                          float64
# zip_code_311xx                          float64
# zip_code_312xx                          float64
# zip_code_313xx                          float64
# zip_code_314xx                          float64
# zip_code_315xx                          float64
# zip_code_316xx                          float64
# zip_code_317xx                          float64
# zip_code_318xx                          float64
# zip_code_319xx                          float64
# zip_code_320xx                          float64
# zip_code_321xx                          float64
# zip_code_322xx                          float64
# zip_code_323xx                          float64
# zip_code_324xx                          float64
# zip_code_325xx                          float64
# zip_code_326xx                          float64
# zip_code_327xx                          float64
# zip_code_328xx                          float64
# zip_code_329xx                          float64
# zip_code_330xx                          float64
# zip_code_331xx                          float64
# zip_code_332xx                          float64
# zip_code_333xx                          float64
# zip_code_334xx                          float64
# zip_code_335xx                          float64
# zip_code_336xx                          float64
# zip_code_337xx                          float64
# zip_code_338xx                          float64
# zip_code_339xx                          float64
# zip_code_340xx                          float64
# zip_code_341xx                          float64
# zip_code_342xx                          float64
# zip_code_343xx                          float64
# zip_code_344xx                          float64
# zip_code_346xx                          float64
# zip_code_347xx                          float64
# zip_code_348xx                          float64
# zip_code_349xx                          float64
# zip_code_350xx                          float64
# zip_code_351xx                          float64
# zip_code_352xx                          float64
# zip_code_353xx                          float64
# zip_code_354xx                          float64
# zip_code_355xx                          float64
# zip_code_356xx                          float64
# zip_code_357xx                          float64
# zip_code_358xx                          float64
# zip_code_359xx                          float64
# zip_code_360xx                          float64
# zip_code_361xx                          float64
# zip_code_362xx                          float64
# zip_code_363xx                          float64
# zip_code_364xx                          float64
# zip_code_365xx                          float64
# zip_code_366xx                          float64
# zip_code_367xx                          float64
# zip_code_368xx                          float64
# zip_code_369xx                          float64
# zip_code_370xx                          float64
# zip_code_371xx                          float64
# zip_code_372xx                          float64
# zip_code_373xx                          float64
# zip_code_374xx                          float64
# zip_code_375xx                          float64
# zip_code_376xx                          float64
# zip_code_377xx                          float64
# zip_code_378xx                          float64
# zip_code_379xx                          float64
# zip_code_380xx                          float64
# zip_code_381xx                          float64
# zip_code_382xx                          float64
# zip_code_383xx                          float64
# zip_code_384xx                          float64
# zip_code_385xx                          float64
# zip_code_386xx                          float64
# zip_code_387xx                          float64
# zip_code_388xx                          float64
# zip_code_389xx                          float64
# zip_code_390xx                          float64
# zip_code_391xx                          float64
# zip_code_392xx                          float64
# zip_code_393xx                          float64
# zip_code_394xx                          float64
# zip_code_395xx                          float64
# zip_code_396xx                          float64
# zip_code_397xx                          float64
# zip_code_398xx                          float64
# zip_code_400xx                          float64
# zip_code_401xx                          float64
# zip_code_402xx                          float64
# zip_code_403xx                          float64
# zip_code_404xx                          float64
# zip_code_405xx                          float64
# zip_code_406xx                          float64
# zip_code_407xx                          float64
# zip_code_408xx                          float64
# zip_code_409xx                          float64
# zip_code_410xx                          float64
# zip_code_411xx                          float64
# zip_code_412xx                          float64
# zip_code_413xx                          float64
# zip_code_414xx                          float64
# zip_code_415xx                          float64
# zip_code_416xx                          float64
# zip_code_417xx                          float64
# zip_code_418xx                          float64
# zip_code_420xx                          float64
# zip_code_421xx                          float64
# zip_code_422xx                          float64
# zip_code_423xx                          float64
# zip_code_424xx                          float64
# zip_code_425xx                          float64
# zip_code_426xx                          float64
# zip_code_427xx                          float64
# zip_code_429xx                          float64
# zip_code_430xx                          float64
# zip_code_431xx                          float64
# zip_code_432xx                          float64
# zip_code_433xx                          float64
# zip_code_434xx                          float64
# zip_code_435xx                          float64
# zip_code_436xx                          float64
# zip_code_437xx                          float64
# zip_code_438xx                          float64
# zip_code_439xx                          float64
# zip_code_440xx                          float64
# zip_code_441xx                          float64
# zip_code_442xx                          float64
# zip_code_443xx                          float64
# zip_code_444xx                          float64
# zip_code_445xx                          float64
# zip_code_446xx                          float64
# zip_code_447xx                          float64
# zip_code_448xx                          float64
# zip_code_449xx                          float64
# zip_code_450xx                          float64
# zip_code_451xx                          float64
# zip_code_452xx                          float64
# zip_code_453xx                          float64
# zip_code_454xx                          float64
# zip_code_455xx                          float64
# zip_code_456xx                          float64
# zip_code_457xx                          float64
# zip_code_458xx                          float64
# zip_code_460xx                          float64
# zip_code_461xx                          float64
# zip_code_462xx                          float64
# zip_code_463xx                          float64
# zip_code_464xx                          float64
# zip_code_465xx                          float64
# zip_code_466xx                          float64
# zip_code_467xx                          float64
# zip_code_468xx                          float64
# zip_code_469xx                          float64
# zip_code_470xx                          float64
# zip_code_471xx                          float64
# zip_code_472xx                          float64
# zip_code_473xx                          float64
# zip_code_474xx                          float64
# zip_code_475xx                          float64
# zip_code_476xx                          float64
# zip_code_477xx                          float64
# zip_code_478xx                          float64
# zip_code_479xx                          float64
# zip_code_480xx                          float64
# zip_code_481xx                          float64
# zip_code_482xx                          float64
# zip_code_483xx                          float64
# zip_code_484xx                          float64
# zip_code_485xx                          float64
# zip_code_486xx                          float64
# zip_code_487xx                          float64
# zip_code_488xx                          float64
# zip_code_489xx                          float64
# zip_code_490xx                          float64
# zip_code_491xx                          float64
# zip_code_492xx                          float64
# zip_code_493xx                          float64
# zip_code_494xx                          float64
# zip_code_495xx                          float64
# zip_code_496xx                          float64
# zip_code_497xx                          float64
# zip_code_498xx                          float64
# zip_code_499xx                          float64
# zip_code_500xx                          float64
# zip_code_501xx                          float64
# zip_code_502xx                          float64
# zip_code_504xx                          float64
# zip_code_506xx                          float64
# zip_code_509xx                          float64
# zip_code_510xx                          float64
# zip_code_513xx                          float64
# zip_code_516xx                          float64
# zip_code_520xx                          float64
# zip_code_521xx                          float64
# zip_code_522xx                          float64
# zip_code_523xx                          float64
# zip_code_524xx                          float64
# zip_code_527xx                          float64
# zip_code_528xx                          float64
# zip_code_530xx                          float64
# zip_code_531xx                          float64
# zip_code_532xx                          float64
# zip_code_534xx                          float64
# zip_code_535xx                          float64
# zip_code_537xx                          float64
# zip_code_538xx                          float64
# zip_code_539xx                          float64
# zip_code_540xx                          float64
# zip_code_541xx                          float64
# zip_code_542xx                          float64
# zip_code_543xx                          float64
# zip_code_544xx                          float64
# zip_code_545xx                          float64
# zip_code_546xx                          float64
# zip_code_547xx                          float64
# zip_code_548xx                          float64
# zip_code_549xx                          float64
# zip_code_550xx                          float64
# zip_code_551xx                          float64
# zip_code_552xx                          float64
# zip_code_553xx                          float64
# zip_code_554xx                          float64
# zip_code_555xx                          float64
# zip_code_556xx                          float64
# zip_code_557xx                          float64
# zip_code_558xx                          float64
# zip_code_559xx                          float64
# zip_code_560xx                          float64
# zip_code_561xx                          float64
# zip_code_562xx                          float64
# zip_code_563xx                          float64
# zip_code_564xx                          float64
# zip_code_565xx                          float64
# zip_code_566xx                          float64
# zip_code_567xx                          float64
# zip_code_568xx                          float64
# zip_code_569xx                          float64
# zip_code_570xx                          float64
# zip_code_571xx                          float64
# zip_code_572xx                          float64
# zip_code_573xx                          float64
# zip_code_574xx                          float64
# zip_code_575xx                          float64
# zip_code_576xx                          float64
# zip_code_577xx                          float64
# zip_code_580xx                          float64
# zip_code_581xx                          float64
# zip_code_582xx                          float64
# zip_code_583xx                          float64
# zip_code_584xx                          float64
# zip_code_585xx                          float64
# zip_code_586xx                          float64
# zip_code_587xx                          float64
# zip_code_588xx                          float64
# zip_code_590xx                          float64
# zip_code_591xx                          float64
# zip_code_592xx                          float64
# zip_code_593xx                          float64
# zip_code_594xx                          float64
# zip_code_595xx                          float64
# zip_code_596xx                          float64
# zip_code_597xx                          float64
# zip_code_598xx                          float64
# zip_code_599xx                          float64
# zip_code_600xx                          float64
# zip_code_601xx                          float64
# zip_code_602xx                          float64
# zip_code_603xx                          float64
# zip_code_604xx                          float64
# zip_code_605xx                          float64
# zip_code_606xx                          float64
# zip_code_607xx                          float64
# zip_code_608xx                          float64
# zip_code_609xx                          float64
# zip_code_610xx                          float64
# zip_code_611xx                          float64
# zip_code_612xx                          float64
# zip_code_613xx                          float64
# zip_code_614xx                          float64
# zip_code_615xx                          float64
# zip_code_616xx                          float64
# zip_code_617xx                          float64
# zip_code_618xx                          float64
# zip_code_619xx                          float64
# zip_code_620xx                          float64
# zip_code_621xx                          float64
# zip_code_622xx                          float64
# zip_code_623xx                          float64
# zip_code_624xx                          float64
# zip_code_625xx                          float64
# zip_code_626xx                          float64
# zip_code_627xx                          float64
# zip_code_628xx                          float64
# zip_code_629xx                          float64
# zip_code_630xx                          float64
# zip_code_631xx                          float64
# zip_code_633xx                          float64
# zip_code_634xx                          float64
# zip_code_635xx                          float64
# zip_code_636xx                          float64
# zip_code_637xx                          float64
# zip_code_638xx                          float64
# zip_code_639xx                          float64
# zip_code_640xx                          float64
# zip_code_641xx                          float64
# zip_code_643xx                          float64
# zip_code_644xx                          float64
# zip_code_645xx                          float64
# zip_code_646xx                          float64
# zip_code_647xx                          float64
# zip_code_648xx                          float64
# zip_code_650xx                          float64
# zip_code_651xx                          float64
# zip_code_652xx                          float64
# zip_code_653xx                          float64
# zip_code_654xx                          float64
# zip_code_655xx                          float64
# zip_code_656xx                          float64
# zip_code_657xx                          float64
# zip_code_658xx                          float64
# zip_code_660xx                          float64
# zip_code_661xx                          float64
# zip_code_662xx                          float64
# zip_code_663xx                          float64
# zip_code_664xx                          float64
# zip_code_665xx                          float64
# zip_code_666xx                          float64
# zip_code_667xx                          float64
# zip_code_668xx                          float64
# zip_code_669xx                          float64
# zip_code_670xx                          float64
# zip_code_671xx                          float64
# zip_code_672xx                          float64
# zip_code_673xx                          float64
# zip_code_674xx                          float64
# zip_code_675xx                          float64
# zip_code_676xx                          float64
# zip_code_677xx                          float64
# zip_code_678xx                          float64
# zip_code_679xx                          float64
# zip_code_680xx                          float64
# zip_code_681xx                          float64
# zip_code_683xx                          float64
# zip_code_684xx                          float64
# zip_code_685xx                          float64
# zip_code_686xx                          float64
# zip_code_687xx                          float64
# zip_code_688xx                          float64
# zip_code_689xx                          float64
# zip_code_690xx                          float64
# zip_code_691xx                          float64
# zip_code_692xx                          float64
# zip_code_693xx                          float64
# zip_code_700xx                          float64
# zip_code_701xx                          float64
# zip_code_702xx                          float64
# zip_code_703xx                          float64
# zip_code_704xx                          float64
# zip_code_705xx                          float64
# zip_code_706xx                          float64
# zip_code_707xx                          float64
# zip_code_708xx                          float64
# zip_code_709xx                          float64
# zip_code_710xx                          float64
# zip_code_711xx                          float64
# zip_code_712xx                          float64
# zip_code_713xx                          float64
# zip_code_714xx                          float64
# zip_code_716xx                          float64
# zip_code_717xx                          float64
# zip_code_718xx                          float64
# zip_code_719xx                          float64
# zip_code_720xx                          float64
# zip_code_721xx                          float64
# zip_code_722xx                          float64
# zip_code_723xx                          float64
# zip_code_724xx                          float64
# zip_code_725xx                          float64
# zip_code_726xx                          float64
# zip_code_727xx                          float64
# zip_code_728xx                          float64
# zip_code_729xx                          float64
# zip_code_730xx                          float64
# zip_code_731xx                          float64
# zip_code_734xx                          float64
# zip_code_735xx                          float64
# zip_code_736xx                          float64
# zip_code_737xx                          float64
# zip_code_738xx                          float64
# zip_code_739xx                          float64
# zip_code_740xx                          float64
# zip_code_741xx                          float64
# zip_code_742xx                          float64
# zip_code_743xx                          float64
# zip_code_744xx                          float64
# zip_code_745xx                          float64
# zip_code_746xx                          float64
# zip_code_747xx                          float64
# zip_code_748xx                          float64
# zip_code_749xx                          float64
# zip_code_750xx                          float64
# zip_code_751xx                          float64
# zip_code_752xx                          float64
# zip_code_753xx                          float64
# zip_code_754xx                          float64
# zip_code_755xx                          float64
# zip_code_756xx                          float64
# zip_code_757xx                          float64
# zip_code_758xx                          float64
# zip_code_759xx                          float64
# zip_code_760xx                          float64
# zip_code_761xx                          float64
# zip_code_762xx                          float64
# zip_code_763xx                          float64
# zip_code_764xx                          float64
# zip_code_765xx                          float64
# zip_code_766xx                          float64
# zip_code_767xx                          float64
# zip_code_768xx                          float64
# zip_code_769xx                          float64
# zip_code_770xx                          float64
# zip_code_772xx                          float64
# zip_code_773xx                          float64
# zip_code_774xx                          float64
# zip_code_775xx                          float64
# zip_code_776xx                          float64
# zip_code_777xx                          float64
# zip_code_778xx                          float64
# zip_code_779xx                          float64
# zip_code_780xx                          float64
# zip_code_781xx                          float64
# zip_code_782xx                          float64
# zip_code_783xx                          float64
# zip_code_784xx                          float64
# zip_code_785xx                          float64
# zip_code_786xx                          float64
# zip_code_787xx                          float64
# zip_code_788xx                          float64
# zip_code_789xx                          float64
# zip_code_790xx                          float64
# zip_code_791xx                          float64
# zip_code_792xx                          float64
# zip_code_793xx                          float64
# zip_code_794xx                          float64
# zip_code_795xx                          float64
# zip_code_796xx                          float64
# zip_code_797xx                          float64
# zip_code_798xx                          float64
# zip_code_799xx                          float64
# zip_code_800xx                          float64
# zip_code_801xx                          float64
# zip_code_802xx                          float64
# zip_code_803xx                          float64
# zip_code_804xx                          float64
# zip_code_805xx                          float64
# zip_code_806xx                          float64
# zip_code_807xx                          float64
# zip_code_808xx                          float64
# zip_code_809xx                          float64
# zip_code_810xx                          float64
# zip_code_811xx                          float64
# zip_code_812xx                          float64
# zip_code_813xx                          float64
# zip_code_814xx                          float64
# zip_code_815xx                          float64
# zip_code_816xx                          float64
# zip_code_820xx                          float64
# zip_code_821xx                          float64
# zip_code_822xx                          float64
# zip_code_823xx                          float64
# zip_code_824xx                          float64
# zip_code_825xx                          float64
# zip_code_826xx                          float64
# zip_code_827xx                          float64
# zip_code_828xx                          float64
# zip_code_829xx                          float64
# zip_code_830xx                          float64
# zip_code_831xx                          float64
# zip_code_832xx                          float64
# zip_code_833xx                          float64
# zip_code_834xx                          float64
# zip_code_835xx                          float64
# zip_code_836xx                          float64
# zip_code_837xx                          float64
# zip_code_838xx                          float64
# zip_code_840xx                          float64
# zip_code_841xx                          float64
# zip_code_843xx                          float64
# zip_code_844xx                          float64
# zip_code_845xx                          float64
# zip_code_846xx                          float64
# zip_code_847xx                          float64
# zip_code_849xx                          float64
# zip_code_850xx                          float64
# zip_code_851xx                          float64
# zip_code_852xx                          float64
# zip_code_853xx                          float64
# zip_code_854xx                          float64
# zip_code_855xx                          float64
# zip_code_856xx                          float64
# zip_code_857xx                          float64
# zip_code_859xx                          float64
# zip_code_860xx                          float64
# zip_code_861xx                          float64
# zip_code_862xx                          float64
# zip_code_863xx                          float64
# zip_code_864xx                          float64
# zip_code_865xx                          float64
# zip_code_870xx                          float64
# zip_code_871xx                          float64
# zip_code_872xx                          float64
# zip_code_873xx                          float64
# zip_code_874xx                          float64
# zip_code_875xx                          float64
# zip_code_877xx                          float64
# zip_code_878xx                          float64
# zip_code_879xx                          float64
# zip_code_880xx                          float64
# zip_code_881xx                          float64
# zip_code_882xx                          float64
# zip_code_883xx                          float64
# zip_code_884xx                          float64
# zip_code_888xx                          float64
# zip_code_889xx                          float64
# zip_code_890xx                          float64
# zip_code_891xx                          float64
# zip_code_893xx                          float64
# zip_code_894xx                          float64
# zip_code_895xx                          float64
# zip_code_896xx                          float64
# zip_code_897xx                          float64
# zip_code_898xx                          float64
# zip_code_900xx                          float64
# zip_code_901xx                          float64
# zip_code_902xx                          float64
# zip_code_903xx                          float64
# zip_code_904xx                          float64
# zip_code_905xx                          float64
# zip_code_906xx                          float64
# zip_code_907xx                          float64
# zip_code_908xx                          float64
# zip_code_909xx                          float64
# zip_code_910xx                          float64
# zip_code_911xx                          float64
# zip_code_912xx                          float64
# zip_code_913xx                          float64
# zip_code_914xx                          float64
# zip_code_915xx                          float64
# zip_code_916xx                          float64
# zip_code_917xx                          float64
# zip_code_918xx                          float64
# zip_code_919xx                          float64
# zip_code_920xx                          float64
# zip_code_921xx                          float64
# zip_code_922xx                          float64
# zip_code_923xx                          float64
# zip_code_924xx                          float64
# zip_code_925xx                          float64
# zip_code_926xx                          float64
# zip_code_927xx                          float64
# zip_code_928xx                          float64
# zip_code_929xx                          float64
# zip_code_930xx                          float64
# zip_code_931xx                          float64
# zip_code_932xx                          float64
# zip_code_933xx                          float64
# zip_code_934xx                          float64
# zip_code_935xx                          float64
# zip_code_936xx                          float64
# zip_code_937xx                          float64
# zip_code_938xx                          float64
# zip_code_939xx                          float64
# zip_code_940xx                          float64
# zip_code_941xx                          float64
# zip_code_942xx                          float64
# zip_code_943xx                          float64
# zip_code_944xx                          float64
# zip_code_945xx                          float64
# zip_code_946xx                          float64
# zip_code_947xx                          float64
# zip_code_948xx                          float64
# zip_code_949xx                          float64
# zip_code_950xx                          float64
# zip_code_951xx                          float64
# zip_code_952xx                          float64
# zip_code_953xx                          float64
# zip_code_954xx                          float64
# zip_code_955xx                          float64
# zip_code_956xx                          float64
# zip_code_957xx                          float64
# zip_code_958xx                          float64
# zip_code_959xx                          float64
# zip_code_960xx                          float64
# zip_code_961xx                          float64
# zip_code_962xx                          float64
# zip_code_963xx                          float64
# zip_code_965xx                          float64
# zip_code_967xx                          float64
# zip_code_968xx                          float64
# zip_code_969xx                          float64
# zip_code_970xx                          float64
# zip_code_971xx                          float64
# zip_code_972xx                          float64
# zip_code_973xx                          float64
# zip_code_974xx                          float64
# zip_code_975xx                          float64
# zip_code_976xx                          float64
# zip_code_977xx                          float64
# zip_code_978xx                          float64
# zip_code_979xx                          float64
# zip_code_980xx                          float64
# zip_code_981xx                          float64
# zip_code_982xx                          float64
# zip_code_983xx                          float64
# zip_code_984xx                          float64
# zip_code_985xx                          float64
# zip_code_986xx                          float64
# zip_code_987xx                          float64
# zip_code_988xx                          float64
# zip_code_989xx                          float64
# zip_code_990xx                          float64
# zip_code_991xx                          float64
# zip_code_992xx                          float64
# zip_code_993xx                          float64
# zip_code_994xx                          float64
# zip_code_995xx                          float64
# zip_code_996xx                          float64
# zip_code_997xx                          float64
# zip_code_998xx                          float64
# zip_code_999xx                          float64
# application_type_Joint App              float64
# sub_grade_A2                            float64
# sub_grade_A3                            float64
# sub_grade_A4                            float64
# sub_grade_A5                            float64
# sub_grade_B1                            float64
# sub_grade_B2                            float64
# sub_grade_B3                            float64
# sub_grade_B4                            float64
# sub_grade_B5                            float64
# sub_grade_C1                            float64
# sub_grade_C2                            float64
# sub_grade_C3                            float64
# sub_grade_C4                            float64
# sub_grade_C5                            float64
# sub_grade_D1                            float64
# sub_grade_D2                            float64
# sub_grade_D3                            float64
# sub_grade_D4                            float64
# sub_grade_D5                            float64
# sub_grade_E1                            float64
# sub_grade_E2                            float64
# sub_grade_E3                            float64
# sub_grade_E4                            float64
# sub_grade_E5                            float64
# sub_grade_F1                            float64
# sub_grade_F2                            float64
# sub_grade_F3                            float64
# sub_grade_F4                            float64
# sub_grade_F5                            float64
# sub_grade_G1                            float64
# sub_grade_G2                            float64
# sub_grade_G3                            float64
# sub_grade_G4                            float64
# sub_grade_G5                            float64
# emp_title_2_Account Manager             float64
# emp_title_2_Accountant                  float64
# emp_title_2_Administrative Assistant    float64
# emp_title_2_Administrator               float64
# emp_title_2_Analyst                     float64
# emp_title_2_Assistant Manager           float64
# emp_title_2_Attorney                    float64
# emp_title_2_Branch Manager              float64
# emp_title_2_CEO                         float64
# emp_title_2_Consultant                  float64
# emp_title_2_Controller                  float64
# emp_title_2_Director                    float64
# emp_title_2_Driver                      float64
# emp_title_2_Electrician                 float64
# emp_title_2_Engineer                    float64
# emp_title_2_Executive Assistant         float64
# emp_title_2_General Manager             float64
# emp_title_2_Manager                     float64
# emp_title_2_Mechanic                    float64
# emp_title_2_Nurse                       float64
# emp_title_2_Office Manager              float64
# emp_title_2_Operations Manager          float64
# emp_title_2_Other                       float64
# emp_title_2_Owner                       float64
# emp_title_2_Paralegal                   float64
# emp_title_2_Police Officer              float64
# emp_title_2_President                   float64
# emp_title_2_Principal                   float64
# emp_title_2_Program Manager             float64
# emp_title_2_Project Manager             float64
# emp_title_2_RN                          float64
# emp_title_2_Registered Nurse            float64
# emp_title_2_Sales                       float64
# emp_title_2_Sales Manager               float64
# emp_title_2_Server                      float64
# emp_title_2_Software Engineer           float64
# emp_title_2_Store Manager               float64
# emp_title_2_Supervisor                  float64
# emp_title_2_Teacher                     float64
# emp_title_2_Technician                  float64
# emp_title_2_Truck Driver                float64
# emp_title_2_Vice President              float64
# emp_title_2_driver                      float64
# emp_title_2_manager                     float64
# emp_title_2_owner                       float64
# emp_title_2_sales                       float64
# emp_title_2_supervisor                  float64
# emp_title_2_teacher                     float64
# emp_title_2_truck driver                float64
# dtypes: float64(1118), object(15)
# memory usage: 992.0+ MB

# %%
#drop OHE source columns & unuseful categorical variables
X_train_10pcnt.drop(columns=['term','verification_status','home_ownership','purpose','zip_code',
                             'addr_state','sub_grade','emp_title_2','application_type', 
                             'grade','emp_title','title', 
                             #ALSO, drop redundant columns that new OHE columns provide the info for
                             'debt_settlement_flag',#ALSO, drop columns clearly not predictive of class
                             'issue_d','last_pymnt_d'],inplace=True) #ALSO, drop date columns

# %%
#REPEAT DROPS for X_test
X_test_10pcnt.drop(columns=['term','verification_status','home_ownership','purpose','zip_code',
                            'addr_state','sub_grade','emp_title_2','application_type', 
                            'grade','emp_title','title', 
                            #ALSO, drop redundant columns that new OHE columns provide the info for
                            'debt_settlement_flag',#ALSO, drop columns clearly not predictive of class
                            'issue_d','last_pymnt_d'],inplace=True) #ALSO, drop date columns

# %%
X_train_10pcnt.head()
# Out:
#     loan_amnt  funded_amnt  int_rate  installment  emp_length  annual_inc  \
# 12    16000.0      16000.0    0.1262       360.95         7.0     55000.0
# 33    25000.0      25000.0    0.1042       536.36         1.0    154000.0
# 38     1000.0       1000.0    0.1199        33.21         9.0     63000.0
# 49     4000.0       4000.0    0.1359       135.92         5.0     35000.0
# 52        NaN          NaN       NaN          NaN         NaN         NaN
#
#       dti  delinq_2yrs  earliest_cr_line  fico_range_low  ...  \
# 12  13.02          0.0           13939.0           710.0  ...
# 33   4.67          1.0            9862.0           680.0  ...
# 38  10.04          1.0           14092.0           660.0  ...
# 49   4.36          0.0           14092.0           710.0  ...
# 52    NaN          NaN               NaN             NaN  ...
#
#     emp_title_2_Technician  emp_title_2_Truck Driver  \
# 12                     0.0                       0.0
# 33                     0.0                       0.0
# 38                     0.0                       0.0
# 49                     0.0                       0.0
# 52                     0.0                       0.0
#
#     emp_title_2_Vice President  emp_title_2_driver  emp_title_2_manager  \
# 12                         0.0                 0.0                  0.0
# 33                         0.0                 0.0                  0.0
# 38                         0.0                 0.0                  0.0
# 49                         0.0                 0.0                  0.0
# 52                         0.0                 0.0                  0.0
#
#     emp_title_2_owner  emp_title_2_sales  emp_title_2_supervisor  \
# 12                0.0                0.0                     0.0
# 33                0.0                0.0                     0.0
# 38                0.0                0.0                     0.0
# 49                0.0                0.0                     0.0
# 52                0.0                0.0                     0.0
#
#     emp_title_2_teacher  emp_title_2_truck driver
# 12                  0.0                       0.0
# 33                  0.0                       0.0
# 38                  0.0                       0.0
# 49                  0.0                       0.0
# 52                  0.0                       0.0
#
# [5 rows x 1118 columns]

# %%
X_test_10pcnt.head()
# Out:
#     loan_amnt  funded_amnt  int_rate  installment  emp_length  annual_inc  \
# 12        NaN          NaN       NaN          NaN         NaN         NaN
# 33        NaN          NaN       NaN          NaN         NaN         NaN
# 38        NaN          NaN       NaN          NaN         NaN         NaN
# 49        NaN          NaN       NaN          NaN         NaN         NaN
# 52    14000.0      14000.0    0.2291       541.28         1.0     60000.0
#
#       dti  delinq_2yrs  earliest_cr_line  fico_range_low  ...  \
# 12    NaN          NaN               NaN             NaN  ...
# 33    NaN          NaN               NaN             NaN  ...
# 38    NaN          NaN               NaN             NaN  ...
# 49    NaN          NaN               NaN             NaN  ...
# 52  21.82          1.0           10166.0           665.0  ...
#
#     emp_title_2_Technician  emp_title_2_Truck Driver  \
# 12                     0.0                       0.0
# 33                     0.0                       0.0
# 38                     0.0                       0.0
# 49                     0.0                       0.0
# 52                     0.0                       0.0
#
#     emp_title_2_Vice President  emp_title_2_driver  emp_title_2_manager  \
# 12                         0.0                 0.0                  0.0
# 33                         0.0                 0.0                  0.0
# 38                         0.0                 0.0                  0.0
# 49                         0.0                 0.0                  0.0
# 52                         0.0                 0.0                  0.0
#
#     emp_title_2_owner  emp_title_2_sales  emp_title_2_supervisor  \
# 12                0.0                0.0                     0.0
# 33                0.0                0.0                     0.0
# 38                0.0                0.0                     0.0
# 49                0.0                0.0                     0.0
# 52                0.0                0.0                     0.0
#
#     emp_title_2_teacher  emp_title_2_truck driver
# 1259919                  NaN                       NaN
# 1259923                  NaN                       NaN
# 1259926                  NaN                       NaN
# 1259939                  NaN                       NaN
# 1259952                  NaN                       NaN
# 1259958                  NaN                       NaN
# 1259977                  NaN                       NaN
# 1259983                  NaN                       NaN
# 1260004                  NaN                       NaN
# 1260027                  NaN                       NaN
# 1260087                  NaN                       NaN
# 1260092                  NaN                       NaN
# 1260117                  NaN                       NaN
# 1260119                  NaN                       NaN
#
# [114663 rows x 1118 columns]

# %%
X_train_10pcnt.info(verbose=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114663 entries, 4 to 1260154
# Data columns (total 1118 columns):
# loan_amnt                               float64
# funded_amnt                             float64
# int_rate                                float64
# installment                             float64
# emp_length                              float64
# annual_inc                              float64
# dti                                     float64
# delinq_2yrs                             float64
# earliest_cr_line                        float64
# fico_range_low                          float64
# fico_range_high                         float64
# inq_last_6mths                          float64
# mths_since_last_delinq                  float64
# mths_since_last_record                  float64
# open_acc                                float64
# pub_rec                                 float64
# revol_bal                               float64
# revol_util                              float64
# total_acc                               float64
# out_prncp                               float64
# out_prncp_inv                           float64
# last_fico_range_high                    float64
# last_fico_range_low                     float64
# collections_12_mths_ex_med              float64
# mths_since_last_major_derog             float64
# policy_code                             float64
# annual_inc_joint                        float64
# dti_joint                               float64
# acc_now_delinq                          float64
# tot_coll_amt                            float64
# tot_cur_bal                             float64
# open_acc_6m                             float64
# open_act_il                             float64
# open_il_12m                             float64
# open_il_24m                             float64
# mths_since_rcnt_il                      float64
# total_bal_il                            float64
# il_util                                 float64
# open_rv_12m                             float64
# open_rv_24m                             float64
# all_util                                float64
# total_rev_hi_lim                        float64
# inq_fi                                  float64
# total_cu_tl                             float64
# inq_last_12m                            float64
# acc_open_past_24mths                    float64
# avg_cur_bal                             float64
# bc_open_to_buy                          float64
# bc_util                                 float64
# chargeoff_within_12_mths                float64
# delinq_amnt                             float64
# mo_sin_old_il_acct                      float64
# mo_sin_old_rev_tl_op                    float64
# mo_sin_rcnt_rev_tl_op                   float64
# mo_sin_rcnt_tl                          float64
# mort_acc                                float64
# mths_since_recent_bc                    float64
# mths_since_recent_bc_dlq                float64
# mths_since_recent_inq                   float64
# mths_since_recent_revol_delinq          float64
# num_accts_ever_120_pd                   float64
# num_actv_bc_tl                          float64
# num_actv_rev_tl                         float64
# num_bc_sats                             float64
# num_bc_tl                               float64
# num_il_tl                               float64
# num_op_rev_tl                           float64
# num_rev_accts                           float64
# num_rev_tl_bal_gt_0                     float64
# num_sats                                float64
# num_tl_120dpd_2m                        float64
# num_tl_30dpd                            float64
# num_tl_90g_dpd_24m                      float64
# num_tl_op_past_12m                      float64
# pct_tl_nvr_dlq                          float64
# percent_bc_gt_75                        float64
# pub_rec_bankruptcies                    float64
# tax_liens                               float64
# tot_hi_cred_lim                         float64
# total_bal_ex_mort                       float64
# total_bc_limit                          float64
# total_il_high_credit_limit              float64
# collection_recovery_fee                 float64
# total_rec_prncp                         float64
# total_rec_int                           float64
# total_rec_late_fee                      float64
# home_ownership_MORTGAGE                 float64
# home_ownership_NONE                     float64
# home_ownership_OTHER                    float64
# home_ownership_OWN                      float64
# home_ownership_RENT                     float64
# purpose_credit_card                     float64
# purpose_debt_consolidation              float64
# purpose_educational                     float64
# purpose_home_improvement                float64
# purpose_house                           float64
# purpose_major_purchase                  float64
# purpose_medical                         float64
# purpose_moving                          float64
# purpose_other                           float64
# purpose_renewable_energy                float64
# purpose_small_business                  float64
# purpose_vacation                        float64
# purpose_wedding                         float64
# zip_code_007xx                          float64
# zip_code_008xx                          float64
# zip_code_009xx                          float64
# zip_code_010xx                          float64
# zip_code_011xx                          float64
# zip_code_012xx                          float64
# zip_code_013xx                          float64
# zip_code_014xx                          float64
# zip_code_015xx                          float64
# zip_code_016xx                          float64
# zip_code_017xx                          float64
# zip_code_018xx                          float64
# zip_code_019xx                          float64
# zip_code_020xx                          float64
# zip_code_021xx                          float64
# zip_code_022xx                          float64
# zip_code_023xx                          float64
# zip_code_024xx                          float64
# zip_code_025xx                          float64
# zip_code_026xx                          float64
# zip_code_027xx                          float64
# zip_code_028xx                          float64
# zip_code_029xx                          float64
# zip_code_030xx                          float64
# zip_code_031xx                          float64
# zip_code_032xx                          float64
# zip_code_033xx                          float64
# zip_code_034xx                          float64
# zip_code_035xx                          float64
# zip_code_036xx                          float64
# zip_code_037xx                          float64
# zip_code_038xx                          float64
# zip_code_039xx                          float64
# zip_code_040xx                          float64
# zip_code_041xx                          float64
# zip_code_042xx                          float64
# zip_code_043xx                          float64
# zip_code_044xx                          float64
# zip_code_045xx                          float64
# zip_code_046xx                          float64
# zip_code_047xx                          float64
# zip_code_048xx                          float64
# zip_code_049xx                          float64
# zip_code_050xx                          float64
# zip_code_051xx                          float64
# zip_code_052xx                          float64
# zip_code_053xx                          float64
# zip_code_054xx                          float64
# zip_code_056xx                          float64
# zip_code_057xx                          float64
# zip_code_058xx                          float64
# zip_code_059xx                          float64
# zip_code_060xx                          float64
# zip_code_061xx                          float64
# zip_code_062xx                          float64
# zip_code_063xx                          float64
# zip_code_064xx                          float64
# zip_code_065xx                          float64
# zip_code_066xx                          float64
# zip_code_067xx                          float64
# zip_code_068xx                          float64
# zip_code_069xx                          float64
# zip_code_070xx                          float64
# zip_code_071xx                          float64
# zip_code_072xx                          float64
# zip_code_073xx                          float64
# zip_code_074xx                          float64
# zip_code_075xx                          float64
# zip_code_076xx                          float64
# zip_code_077xx                          float64
# zip_code_078xx                          float64
# zip_code_079xx                          float64
# zip_code_080xx                          float64
# zip_code_081xx                          float64
# zip_code_082xx                          float64
# zip_code_083xx                          float64
# zip_code_084xx                          float64
# zip_code_085xx                          float64
# zip_code_086xx                          float64
# zip_code_087xx                          float64
# zip_code_088xx                          float64
# zip_code_089xx                          float64
# zip_code_090xx                          float64
# zip_code_091xx                          float64
# zip_code_092xx                          float64
# zip_code_093xx                          float64
# zip_code_094xx                          float64
# zip_code_096xx                          float64
# zip_code_097xx                          float64
# zip_code_098xx                          float64
# zip_code_100xx                          float64
# zip_code_101xx                          float64
# zip_code_102xx                          float64
# zip_code_103xx                          float64
# zip_code_104xx                          float64
# zip_code_105xx                          float64
# zip_code_106xx                          float64
# zip_code_107xx                          float64
# zip_code_108xx                          float64
# zip_code_109xx                          float64
# zip_code_110xx                          float64
# zip_code_111xx                          float64
# zip_code_112xx                          float64
# zip_code_113xx                          float64
# zip_code_114xx                          float64
# zip_code_115xx                          float64
# zip_code_116xx                          float64
# zip_code_117xx                          float64
# zip_code_118xx                          float64
# zip_code_119xx                          float64
# zip_code_120xx                          float64
# zip_code_121xx                          float64
# zip_code_122xx                          float64
# zip_code_123xx                          float64
# zip_code_124xx                          float64
# zip_code_125xx                          float64
# zip_code_126xx                          float64
# zip_code_127xx                          float64
# zip_code_128xx                          float64
# zip_code_129xx                          float64
# zip_code_130xx                          float64
# zip_code_131xx                          float64
# zip_code_132xx                          float64
# zip_code_133xx                          float64
# zip_code_134xx                          float64
# zip_code_135xx                          float64
# zip_code_136xx                          float64
# zip_code_137xx                          float64
# zip_code_138xx                          float64
# zip_code_139xx                          float64
# zip_code_140xx                          float64
# zip_code_141xx                          float64
# zip_code_142xx                          float64
# zip_code_143xx                          float64
# zip_code_144xx                          float64
# zip_code_145xx                          float64
# zip_code_146xx                          float64
# zip_code_147xx                          float64
# zip_code_148xx                          float64
# zip_code_149xx                          float64
# zip_code_150xx                          float64
# zip_code_151xx                          float64
# zip_code_152xx                          float64
# zip_code_153xx                          float64
# zip_code_154xx                          float64
# zip_code_155xx                          float64
# zip_code_156xx                          float64
# zip_code_157xx                          float64
# zip_code_158xx                          float64
# zip_code_159xx                          float64
# zip_code_160xx                          float64
# zip_code_161xx                          float64
# zip_code_162xx                          float64
# zip_code_163xx                          float64
# zip_code_164xx                          float64
# zip_code_165xx                          float64
# zip_code_166xx                          float64
# zip_code_167xx                          float64
# zip_code_168xx                          float64
# zip_code_169xx                          float64
# zip_code_170xx                          float64
# zip_code_171xx                          float64
# zip_code_172xx                          float64
# zip_code_173xx                          float64
# zip_code_174xx                          float64
# zip_code_175xx                          float64
# zip_code_176xx                          float64
# zip_code_177xx                          float64
# zip_code_178xx                          float64
# zip_code_179xx                          float64
# zip_code_180xx                          float64
# zip_code_181xx                          float64
# zip_code_182xx                          float64
# zip_code_183xx                          float64
# zip_code_184xx                          float64
# zip_code_185xx                          float64
# zip_code_186xx                          float64
# zip_code_187xx                          float64
# zip_code_188xx                          float64
# zip_code_189xx                          float64
# zip_code_190xx                          float64
# zip_code_191xx                          float64
# zip_code_193xx                          float64
# zip_code_194xx                          float64
# zip_code_195xx                          float64
# zip_code_196xx                          float64
# zip_code_197xx                          float64
# zip_code_198xx                          float64
# zip_code_199xx                          float64
# zip_code_200xx                          float64
# zip_code_201xx                          float64
# zip_code_202xx                          float64
# zip_code_203xx                          float64
# zip_code_204xx                          float64
# zip_code_205xx                          float64
# zip_code_206xx                          float64
# zip_code_207xx                          float64
# zip_code_208xx                          float64
# zip_code_209xx                          float64
# zip_code_210xx                          float64
# zip_code_211xx                          float64
# zip_code_212xx                          float64
# zip_code_214xx                          float64
# zip_code_215xx                          float64
# zip_code_216xx                          float64
# zip_code_217xx                          float64
# zip_code_218xx                          float64
# zip_code_219xx                          float64
# zip_code_220xx                          float64
# zip_code_221xx                          float64
# zip_code_222xx                          float64
# zip_code_223xx                          float64
# zip_code_224xx                          float64
# zip_code_225xx                          float64
# zip_code_226xx                          float64
# zip_code_227xx                          float64
# zip_code_228xx                          float64
# zip_code_229xx                          float64
# zip_code_230xx                          float64
# zip_code_231xx                          float64
# zip_code_232xx                          float64
# zip_code_233xx                          float64
# zip_code_234xx                          float64
# zip_code_235xx                          float64
# zip_code_236xx                          float64
# zip_code_237xx                          float64
# zip_code_238xx                          float64
# zip_code_239xx                          float64
# zip_code_240xx                          float64
# zip_code_241xx                          float64
# zip_code_242xx                          float64
# zip_code_243xx                          float64
# zip_code_244xx                          float64
# zip_code_245xx                          float64
# zip_code_246xx                          float64
# zip_code_247xx                          float64
# zip_code_248xx                          float64
# zip_code_249xx                          float64
# zip_code_250xx                          float64
# zip_code_251xx                          float64
# zip_code_252xx                          float64
# zip_code_253xx                          float64
# zip_code_254xx                          float64
# zip_code_255xx                          float64
# zip_code_256xx                          float64
# zip_code_257xx                          float64
# zip_code_258xx                          float64
# zip_code_259xx                          float64
# zip_code_260xx                          float64
# zip_code_261xx                          float64
# zip_code_262xx                          float64
# zip_code_263xx                          float64
# zip_code_264xx                          float64
# zip_code_265xx                          float64
# zip_code_266xx                          float64
# zip_code_267xx                          float64
# zip_code_268xx                          float64
# zip_code_269xx                          float64
# zip_code_270xx                          float64
# zip_code_271xx                          float64
# zip_code_272xx                          float64
# zip_code_273xx                          float64
# zip_code_274xx                          float64
# zip_code_275xx                          float64
# zip_code_276xx                          float64
# zip_code_277xx                          float64
# zip_code_278xx                          float64
# zip_code_279xx                          float64
# zip_code_280xx                          float64
# zip_code_281xx                          float64
# zip_code_282xx                          float64
# zip_code_283xx                          float64
# zip_code_284xx                          float64
# zip_code_285xx                          float64
# zip_code_286xx                          float64
# zip_code_287xx                          float64
# zip_code_288xx                          float64
# zip_code_289xx                          float64
# zip_code_290xx                          float64
# zip_code_291xx                          float64
# zip_code_292xx                          float64
# zip_code_293xx                          float64
# zip_code_294xx                          float64
# zip_code_295xx                          float64
# zip_code_296xx                          float64
# zip_code_297xx                          float64
# zip_code_298xx                          float64
# zip_code_299xx                          float64
# zip_code_300xx                          float64
# zip_code_301xx                          float64
# zip_code_302xx                          float64
# zip_code_303xx                          float64
# zip_code_304xx                          float64
# zip_code_305xx                          float64
# zip_code_306xx                          float64
# zip_code_307xx                          float64
# zip_code_308xx                          float64
# zip_code_309xx                          float64
# zip_code_310xx                          float64
# zip_code_311xx                          float64
# zip_code_312xx                          float64
# zip_code_313xx                          float64
# zip_code_314xx                          float64
# zip_code_315xx                          float64
# zip_code_316xx                          float64
# zip_code_317xx                          float64
# zip_code_318xx                          float64
# zip_code_319xx                          float64
# zip_code_320xx                          float64
# zip_code_321xx                          float64
# zip_code_322xx                          float64
# zip_code_323xx                          float64
# zip_code_324xx                          float64
# zip_code_325xx                          float64
# zip_code_326xx                          float64
# zip_code_327xx                          float64
# zip_code_328xx                          float64
# zip_code_329xx                          float64
# zip_code_330xx                          float64
# zip_code_331xx                          float64
# zip_code_332xx                          float64
# zip_code_333xx                          float64
# zip_code_334xx                          float64
# zip_code_335xx                          float64
# zip_code_336xx                          float64
# zip_code_337xx                          float64
# zip_code_338xx                          float64
# zip_code_339xx                          float64
# zip_code_340xx                          float64
# zip_code_341xx                          float64
# zip_code_342xx                          float64
# zip_code_343xx                          float64
# zip_code_344xx                          float64
# zip_code_346xx                          float64
# zip_code_347xx                          float64
# zip_code_348xx                          float64
# zip_code_349xx                          float64
# zip_code_350xx                          float64
# zip_code_351xx                          float64
# zip_code_352xx                          float64
# zip_code_353xx                          float64
# zip_code_354xx                          float64
# zip_code_355xx                          float64
# zip_code_356xx                          float64
# zip_code_357xx                          float64
# zip_code_358xx                          float64
# zip_code_359xx                          float64
# zip_code_360xx                          float64
# zip_code_361xx                          float64
# zip_code_362xx                          float64
# zip_code_363xx                          float64
# zip_code_364xx                          float64
# zip_code_365xx                          float64
# zip_code_366xx                          float64
# zip_code_367xx                          float64
# zip_code_368xx                          float64
# zip_code_369xx                          float64
# zip_code_370xx                          float64
# zip_code_371xx                          float64
# zip_code_372xx                          float64
# zip_code_373xx                          float64
# zip_code_374xx                          float64
# zip_code_375xx                          float64
# zip_code_376xx                          float64
# zip_code_377xx                          float64
# zip_code_378xx                          float64
# zip_code_379xx                          float64
# zip_code_380xx                          float64
# zip_code_381xx                          float64
# zip_code_382xx                          float64
# zip_code_383xx                          float64
# zip_code_384xx                          float64
# zip_code_385xx                          float64
# zip_code_386xx                          float64
# zip_code_387xx                          float64
# zip_code_388xx                          float64
# zip_code_389xx                          float64
# zip_code_390xx                          float64
# zip_code_391xx                          float64
# zip_code_392xx                          float64
# zip_code_393xx                          float64
# zip_code_394xx                          float64
# zip_code_395xx                          float64
# zip_code_396xx                          float64
# zip_code_397xx                          float64
# zip_code_398xx                          float64
# zip_code_400xx                          float64
# zip_code_401xx                          float64
# zip_code_402xx                          float64
# zip_code_403xx                          float64
# zip_code_404xx                          float64
# zip_code_405xx                          float64
# zip_code_406xx                          float64
# zip_code_407xx                          float64
# zip_code_408xx                          float64
# zip_code_409xx                          float64
# zip_code_410xx                          float64
# zip_code_411xx                          float64
# zip_code_412xx                          float64
# zip_code_413xx                          float64
# zip_code_414xx                          float64
# zip_code_415xx                          float64
# zip_code_416xx                          float64
# zip_code_417xx                          float64
# zip_code_418xx                          float64
# zip_code_420xx                          float64
# zip_code_421xx                          float64
# zip_code_422xx                          float64
# zip_code_423xx                          float64
# zip_code_424xx                          float64
# zip_code_425xx                          float64
# zip_code_426xx                          float64
# zip_code_427xx                          float64
# zip_code_429xx                          float64
# zip_code_430xx                          float64
# zip_code_431xx                          float64
# zip_code_432xx                          float64
# zip_code_433xx                          float64
# zip_code_434xx                          float64
# zip_code_435xx                          float64
# zip_code_436xx                          float64
# zip_code_437xx                          float64
# zip_code_438xx                          float64
# zip_code_439xx                          float64
# zip_code_440xx                          float64
# zip_code_441xx                          float64
# zip_code_442xx                          float64
# zip_code_443xx                          float64
# zip_code_444xx                          float64
# zip_code_445xx                          float64
# zip_code_446xx                          float64
# zip_code_447xx                          float64
# zip_code_448xx                          float64
# zip_code_449xx                          float64
# zip_code_450xx                          float64
# zip_code_451xx                          float64
# zip_code_452xx                          float64
# zip_code_453xx                          float64
# zip_code_454xx                          float64
# zip_code_455xx                          float64
# zip_code_456xx                          float64
# zip_code_457xx                          float64
# zip_code_458xx                          float64
# zip_code_460xx                          float64
# zip_code_461xx                          float64
# zip_code_462xx                          float64
# zip_code_463xx                          float64
# zip_code_464xx                          float64
# zip_code_465xx                          float64
# zip_code_466xx                          float64
# zip_code_467xx                          float64
# zip_code_468xx                          float64
# zip_code_469xx                          float64
# zip_code_470xx                          float64
# zip_code_471xx                          float64
# zip_code_472xx                          float64
# zip_code_473xx                          float64
# zip_code_474xx                          float64
# zip_code_475xx                          float64
# zip_code_476xx                          float64
# zip_code_477xx                          float64
# zip_code_478xx                          float64
# zip_code_479xx                          float64
# zip_code_480xx                          float64
# zip_code_481xx                          float64
# zip_code_482xx                          float64
# zip_code_483xx                          float64
# zip_code_484xx                          float64
# zip_code_485xx                          float64
# zip_code_486xx                          float64
# zip_code_487xx                          float64
# zip_code_488xx                          float64
# zip_code_489xx                          float64
# zip_code_490xx                          float64
# zip_code_491xx                          float64
# zip_code_492xx                          float64
# zip_code_493xx                          float64
# zip_code_494xx                          float64
# zip_code_495xx                          float64
# zip_code_496xx                          float64
# zip_code_497xx                          float64
# zip_code_498xx                          float64
# zip_code_499xx                          float64
# zip_code_500xx                          float64
# zip_code_501xx                          float64
# zip_code_502xx                          float64
# zip_code_504xx                          float64
# zip_code_506xx                          float64
# zip_code_509xx                          float64
# zip_code_510xx                          float64
# zip_code_513xx                          float64
# zip_code_516xx                          float64
# zip_code_520xx                          float64
# zip_code_521xx                          float64
# zip_code_522xx                          float64
# zip_code_523xx                          float64
# zip_code_524xx                          float64
# zip_code_527xx                          float64
# zip_code_528xx                          float64
# zip_code_530xx                          float64
# zip_code_531xx                          float64
# zip_code_532xx                          float64
# zip_code_534xx                          float64
# zip_code_535xx                          float64
# zip_code_537xx                          float64
# zip_code_538xx                          float64
# zip_code_539xx                          float64
# zip_code_540xx                          float64
# zip_code_541xx                          float64
# zip_code_542xx                          float64
# zip_code_543xx                          float64
# zip_code_544xx                          float64
# zip_code_545xx                          float64
# zip_code_546xx                          float64
# zip_code_547xx                          float64
# zip_code_548xx                          float64
# zip_code_549xx                          float64
# zip_code_550xx                          float64
# zip_code_551xx                          float64
# zip_code_552xx                          float64
# zip_code_553xx                          float64
# zip_code_554xx                          float64
# zip_code_555xx                          float64
# zip_code_556xx                          float64
# zip_code_557xx                          float64
# zip_code_558xx                          float64
# zip_code_559xx                          float64
# zip_code_560xx                          float64
# zip_code_561xx                          float64
# zip_code_562xx                          float64
# zip_code_563xx                          float64
# zip_code_564xx                          float64
# zip_code_565xx                          float64
# zip_code_566xx                          float64
# zip_code_567xx                          float64
# zip_code_568xx                          float64
# zip_code_569xx                          float64
# zip_code_570xx                          float64
# zip_code_571xx                          float64
# zip_code_572xx                          float64
# zip_code_573xx                          float64
# zip_code_574xx                          float64
# zip_code_575xx                          float64
# zip_code_576xx                          float64
# zip_code_577xx                          float64
# zip_code_580xx                          float64
# zip_code_581xx                          float64
# zip_code_582xx                          float64
# zip_code_583xx                          float64
# zip_code_584xx                          float64
# zip_code_585xx                          float64
# zip_code_586xx                          float64
# zip_code_587xx                          float64
# zip_code_588xx                          float64
# zip_code_590xx                          float64
# zip_code_591xx                          float64
# zip_code_592xx                          float64
# zip_code_593xx                          float64
# zip_code_594xx                          float64
# zip_code_595xx                          float64
# zip_code_596xx                          float64
# zip_code_597xx                          float64
# zip_code_598xx                          float64
# zip_code_599xx                          float64
# zip_code_600xx                          float64
# zip_code_601xx                          float64
# zip_code_602xx                          float64
# zip_code_603xx                          float64
# zip_code_604xx                          float64
# zip_code_605xx                          float64
# zip_code_606xx                          float64
# zip_code_607xx                          float64
# zip_code_608xx                          float64
# zip_code_609xx                          float64
# zip_code_610xx                          float64
# zip_code_611xx                          float64
# zip_code_612xx                          float64
# zip_code_613xx                          float64
# zip_code_614xx                          float64
# zip_code_615xx                          float64
# zip_code_616xx                          float64
# zip_code_617xx                          float64
# zip_code_618xx                          float64
# zip_code_619xx                          float64
# zip_code_620xx                          float64
# zip_code_621xx                          float64
# zip_code_622xx                          float64
# zip_code_623xx                          float64
# zip_code_624xx                          float64
# zip_code_625xx                          float64
# zip_code_626xx                          float64
# zip_code_627xx                          float64
# zip_code_628xx                          float64
# zip_code_629xx                          float64
# zip_code_630xx                          float64
# zip_code_631xx                          float64
# zip_code_633xx                          float64
# zip_code_634xx                          float64
# zip_code_635xx                          float64
# zip_code_636xx                          float64
# zip_code_637xx                          float64
# zip_code_638xx                          float64
# zip_code_639xx                          float64
# zip_code_640xx                          float64
# zip_code_641xx                          float64
# zip_code_643xx                          float64
# zip_code_644xx                          float64
# zip_code_645xx                          float64
# zip_code_646xx                          float64
# zip_code_647xx                          float64
# zip_code_648xx                          float64
# zip_code_650xx                          float64
# zip_code_651xx                          float64
# zip_code_652xx                          float64
# zip_code_653xx                          float64
# zip_code_654xx                          float64
# zip_code_655xx                          float64
# zip_code_656xx                          float64
# zip_code_657xx                          float64
# zip_code_658xx                          float64
# zip_code_660xx                          float64
# zip_code_661xx                          float64
# zip_code_662xx                          float64
# zip_code_663xx                          float64
# zip_code_664xx                          float64
# zip_code_665xx                          float64
# zip_code_666xx                          float64
# zip_code_667xx                          float64
# zip_code_668xx                          float64
# zip_code_669xx                          float64
# zip_code_670xx                          float64
# zip_code_671xx                          float64
# zip_code_672xx                          float64
# zip_code_673xx                          float64
# zip_code_674xx                          float64
# zip_code_675xx                          float64
# zip_code_676xx                          float64
# zip_code_677xx                          float64
# zip_code_678xx                          float64
# zip_code_679xx                          float64
# zip_code_680xx                          float64
# zip_code_681xx                          float64
# zip_code_683xx                          float64
# zip_code_684xx                          float64
# zip_code_685xx                          float64
# zip_code_686xx                          float64
# zip_code_687xx                          float64
# zip_code_688xx                          float64
# zip_code_689xx                          float64
# zip_code_690xx                          float64
# zip_code_691xx                          float64
# zip_code_692xx                          float64
# zip_code_693xx                          float64
# zip_code_700xx                          float64
# zip_code_701xx                          float64
# zip_code_702xx                          float64
# zip_code_703xx                          float64
# zip_code_704xx                          float64
# zip_code_705xx                          float64
# zip_code_706xx                          float64
# zip_code_707xx                          float64
# zip_code_708xx                          float64
# zip_code_709xx                          float64
# zip_code_710xx                          float64
# zip_code_711xx                          float64
# zip_code_712xx                          float64
# zip_code_713xx                          float64
# zip_code_714xx                          float64
# zip_code_716xx                          float64
# zip_code_717xx                          float64
# zip_code_718xx                          float64
# zip_code_719xx                          float64
# zip_code_720xx                          float64
# zip_code_721xx                          float64
# zip_code_722xx                          float64
# zip_code_723xx                          float64
# zip_code_724xx                          float64
# zip_code_725xx                          float64
# zip_code_726xx                          float64
# zip_code_727xx                          float64
# zip_code_728xx                          float64
# zip_code_729xx                          float64
# zip_code_730xx                          float64
# zip_code_731xx                          float64
# zip_code_734xx                          float64
# zip_code_735xx                          float64
# zip_code_736xx                          float64
# zip_code_737xx                          float64
# zip_code_738xx                          float64
# zip_code_739xx                          float64
# zip_code_740xx                          float64
# zip_code_741xx                          float64
# zip_code_742xx                          float64
# zip_code_743xx                          float64
# zip_code_744xx                          float64
# zip_code_745xx                          float64
# zip_code_746xx                          float64
# zip_code_747xx                          float64
# zip_code_748xx                          float64
# zip_code_749xx                          float64
# zip_code_750xx                          float64
# zip_code_751xx                          float64
# zip_code_752xx                          float64
# zip_code_753xx                          float64
# zip_code_754xx                          float64
# zip_code_755xx                          float64
# zip_code_756xx                          float64
# zip_code_757xx                          float64
# zip_code_758xx                          float64
# zip_code_759xx                          float64
# zip_code_760xx                          float64
# zip_code_761xx                          float64
# zip_code_762xx                          float64
# zip_code_763xx                          float64
# zip_code_764xx                          float64
# zip_code_765xx                          float64
# zip_code_766xx                          float64
# zip_code_767xx                          float64
# zip_code_768xx                          float64
# zip_code_769xx                          float64
# zip_code_770xx                          float64
# zip_code_772xx                          float64
# zip_code_773xx                          float64
# zip_code_774xx                          float64
# zip_code_775xx                          float64
# zip_code_776xx                          float64
# zip_code_777xx                          float64
# zip_code_778xx                          float64
# zip_code_779xx                          float64
# zip_code_780xx                          float64
# zip_code_781xx                          float64
# zip_code_782xx                          float64
# zip_code_783xx                          float64
# zip_code_784xx                          float64
# zip_code_785xx                          float64
# zip_code_786xx                          float64
# zip_code_787xx                          float64
# zip_code_788xx                          float64
# zip_code_789xx                          float64
# zip_code_790xx                          float64
# zip_code_791xx                          float64
# zip_code_792xx                          float64
# zip_code_793xx                          float64
# zip_code_794xx                          float64
# zip_code_795xx                          float64
# zip_code_796xx                          float64
# zip_code_797xx                          float64
# zip_code_798xx                          float64
# zip_code_799xx                          float64
# zip_code_800xx                          float64
# zip_code_801xx                          float64
# zip_code_802xx                          float64
# zip_code_803xx                          float64
# zip_code_804xx                          float64
# zip_code_805xx                          float64
# zip_code_806xx                          float64
# zip_code_807xx                          float64
# zip_code_808xx                          float64
# zip_code_809xx                          float64
# zip_code_810xx                          float64
# zip_code_811xx                          float64
# zip_code_812xx                          float64
# zip_code_813xx                          float64
# zip_code_814xx                          float64
# zip_code_815xx                          float64
# zip_code_816xx                          float64
# zip_code_820xx                          float64
# zip_code_821xx                          float64
# zip_code_822xx                          float64
# zip_code_823xx                          float64
# zip_code_824xx                          float64
# zip_code_825xx                          float64
# zip_code_826xx                          float64
# zip_code_827xx                          float64
# zip_code_828xx                          float64
# zip_code_829xx                          float64
# zip_code_830xx                          float64
# zip_code_831xx                          float64
# zip_code_832xx                          float64
# zip_code_833xx                          float64
# zip_code_834xx                          float64
# zip_code_835xx                          float64
# zip_code_836xx                          float64
# zip_code_837xx                          float64
# zip_code_838xx                          float64
# zip_code_840xx                          float64
# zip_code_841xx                          float64
# zip_code_843xx                          float64
# zip_code_844xx                          float64
# zip_code_845xx                          float64
# zip_code_846xx                          float64
# zip_code_847xx                          float64
# zip_code_849xx                          float64
# zip_code_850xx                          float64
# zip_code_851xx                          float64
# zip_code_852xx                          float64
# zip_code_853xx                          float64
# zip_code_854xx                          float64
# zip_code_855xx                          float64
# zip_code_856xx                          float64
# zip_code_857xx                          float64
# zip_code_859xx                          float64
# zip_code_860xx                          float64
# zip_code_861xx                          float64
# zip_code_862xx                          float64
# zip_code_863xx                          float64
# zip_code_864xx                          float64
# zip_code_865xx                          float64
# zip_code_870xx                          float64
# zip_code_871xx                          float64
# zip_code_872xx                          float64
# zip_code_873xx                          float64
# zip_code_874xx                          float64
# zip_code_875xx                          float64
# zip_code_877xx                          float64
# zip_code_878xx                          float64
# zip_code_879xx                          float64
# zip_code_880xx                          float64
# zip_code_881xx                          float64
# zip_code_882xx                          float64
# zip_code_883xx                          float64
# zip_code_884xx                          float64
# zip_code_888xx                          float64
# zip_code_889xx                          float64
# zip_code_890xx                          float64
# zip_code_891xx                          float64
# zip_code_893xx                          float64
# zip_code_894xx                          float64
# zip_code_895xx                          float64
# zip_code_896xx                          float64
# zip_code_897xx                          float64
# zip_code_898xx                          float64
# zip_code_900xx                          float64
# zip_code_901xx                          float64
# zip_code_902xx                          float64
# zip_code_903xx                          float64
# zip_code_904xx                          float64
# zip_code_905xx                          float64
# zip_code_906xx                          float64
# zip_code_907xx                          float64
# zip_code_908xx                          float64
# zip_code_909xx                          float64
# zip_code_910xx                          float64
# zip_code_911xx                          float64
# zip_code_912xx                          float64
# zip_code_913xx                          float64
# zip_code_914xx                          float64
# zip_code_915xx                          float64
# zip_code_916xx                          float64
# zip_code_917xx                          float64
# zip_code_918xx                          float64
# zip_code_919xx                          float64
# zip_code_920xx                          float64
# zip_code_921xx                          float64
# zip_code_922xx                          float64
# zip_code_923xx                          float64
# zip_code_924xx                          float64
# zip_code_925xx                          float64
# zip_code_926xx                          float64
# zip_code_927xx                          float64
# zip_code_928xx                          float64
# zip_code_929xx                          float64
# zip_code_930xx                          float64
# zip_code_931xx                          float64
# zip_code_932xx                          float64
# zip_code_933xx                          float64
# zip_code_934xx                          float64
# zip_code_935xx                          float64
# zip_code_936xx                          float64
# zip_code_937xx                          float64
# zip_code_938xx                          float64
# zip_code_939xx                          float64
# zip_code_940xx                          float64
# zip_code_941xx                          float64
# zip_code_942xx                          float64
# zip_code_943xx                          float64
# zip_code_944xx                          float64
# zip_code_945xx                          float64
# zip_code_946xx                          float64
# zip_code_947xx                          float64
# zip_code_948xx                          float64
# zip_code_949xx                          float64
# zip_code_950xx                          float64
# zip_code_951xx                          float64
# zip_code_952xx                          float64
# zip_code_953xx                          float64
# zip_code_954xx                          float64
# zip_code_955xx                          float64
# zip_code_956xx                          float64
# zip_code_957xx                          float64
# zip_code_958xx                          float64
# zip_code_959xx                          float64
# zip_code_960xx                          float64
# zip_code_961xx                          float64
# zip_code_962xx                          float64
# zip_code_963xx                          float64
# zip_code_965xx                          float64
# zip_code_967xx                          float64
# zip_code_968xx                          float64
# zip_code_969xx                          float64
# zip_code_970xx                          float64
# zip_code_971xx                          float64
# zip_code_972xx                          float64
# zip_code_973xx                          float64
# zip_code_974xx                          float64
# zip_code_975xx                          float64
# zip_code_976xx                          float64
# zip_code_977xx                          float64
# zip_code_978xx                          float64
# zip_code_979xx                          float64
# zip_code_980xx                          float64
# zip_code_981xx                          float64
# zip_code_982xx                          float64
# zip_code_983xx                          float64
# zip_code_984xx                          float64
# zip_code_985xx                          float64
# zip_code_986xx                          float64
# zip_code_987xx                          float64
# zip_code_988xx                          float64
# zip_code_989xx                          float64
# zip_code_990xx                          float64
# zip_code_991xx                          float64
# zip_code_992xx                          float64
# zip_code_993xx                          float64
# zip_code_994xx                          float64
# zip_code_995xx                          float64
# zip_code_996xx                          float64
# zip_code_997xx                          float64
# zip_code_998xx                          float64
# zip_code_999xx                          float64
# application_type_Joint App              float64
# sub_grade_A2                            float64
# sub_grade_A3                            float64
# sub_grade_A4                            float64
# sub_grade_A5                            float64
# sub_grade_B1                            float64
# sub_grade_B2                            float64
# sub_grade_B3                            float64
# sub_grade_B4                            float64
# sub_grade_B5                            float64
# sub_grade_C1                            float64
# sub_grade_C2                            float64
# sub_grade_C3                            float64
# sub_grade_C4                            float64
# sub_grade_C5                            float64
# sub_grade_D1                            float64
# sub_grade_D2                            float64
# sub_grade_D3                            float64
# sub_grade_D4                            float64
# sub_grade_D5                            float64
# sub_grade_E1                            float64
# sub_grade_E2                            float64
# sub_grade_E3                            float64
# sub_grade_E4                            float64
# sub_grade_E5                            float64
# sub_grade_F1                            float64
# sub_grade_F2                            float64
# sub_grade_F3                            float64
# sub_grade_F4                            float64
# sub_grade_F5                            float64
# sub_grade_G1                            float64
# sub_grade_G2                            float64
# sub_grade_G3                            float64
# sub_grade_G4                            float64
# sub_grade_G5                            float64
# emp_title_2_Account Manager             float64
# emp_title_2_Accountant                  float64
# emp_title_2_Administrative Assistant    float64
# emp_title_2_Administrator               float64
# emp_title_2_Analyst                     float64
# emp_title_2_Assistant Manager           float64
# emp_title_2_Attorney                    float64
# emp_title_2_Branch Manager              float64
# emp_title_2_CEO                         float64
# emp_title_2_Consultant                  float64
# emp_title_2_Controller                  float64
# emp_title_2_Director                    float64
# emp_title_2_Driver                      float64
# emp_title_2_Electrician                 float64
# emp_title_2_Engineer                    float64
# emp_title_2_Executive Assistant         float64
# emp_title_2_General Manager             float64
# emp_title_2_Manager                     float64
# emp_title_2_Mechanic                    float64
# emp_title_2_Nurse                       float64
# emp_title_2_Office Manager              float64
# emp_title_2_Operations Manager          float64
# emp_title_2_Other                       float64
# emp_title_2_Owner                       float64
# emp_title_2_Paralegal                   float64
# emp_title_2_Police Officer              float64
# emp_title_2_President                   float64
# emp_title_2_Principal                   float64
# emp_title_2_Program Manager             float64
# emp_title_2_Project Manager             float64
# emp_title_2_RN                          float64
# emp_title_2_Registered Nurse            float64
# emp_title_2_Sales                       float64
# emp_title_2_Sales Manager               float64
# emp_title_2_Server                      float64
# emp_title_2_Software Engineer           float64
# emp_title_2_Store Manager               float64
# emp_title_2_Supervisor                  float64
# emp_title_2_Teacher                     float64
# emp_title_2_Technician                  float64
# emp_title_2_Truck Driver                float64
# emp_title_2_Vice President              float64
# emp_title_2_driver                      float64
# emp_title_2_manager                     float64
# emp_title_2_owner                       float64
# emp_title_2_sales                       float64
# emp_title_2_supervisor                  float64
# emp_title_2_teacher                     float64
# emp_title_2_truck driver                float64
# dtypes: float64(1118)
# memory usage: 978.9 MB

# %% [markdown]
# ### Standard Scaling to Prep for Principal Component Analysis

# %%
# Standardize data
scaler = StandardScaler()
scaler.fit(X_train_10pcnt)
X_train_10pcnt_scaled = scaler.transform(X_train_10pcnt)
X_test_10pcnt_scaled = scaler.transform(X_test_10pcnt)

# %%
X_train_10pcnt[X_train_10pcnt.isna()]
# Out:
#          loan_amnt  funded_amnt  int_rate  installment  emp_length  \
# 4              NaN          NaN       NaN          NaN         NaN
# 13             NaN          NaN       NaN          NaN         NaN
# 32             NaN          NaN       NaN          NaN         NaN
# 38             NaN          NaN       NaN          NaN         NaN
# 56             NaN          NaN       NaN          NaN         NaN
# 57             NaN          NaN       NaN          NaN         NaN
# 59             NaN          NaN       NaN          NaN         NaN
# 77             NaN          NaN       NaN          NaN         NaN
# 78             NaN          NaN       NaN          NaN         NaN
# 89             NaN          NaN       NaN          NaN         NaN
# 149            NaN          NaN       NaN          NaN         NaN
# 178            NaN          NaN       NaN          NaN         NaN
# 186            NaN          NaN       NaN          NaN         NaN
# 199            NaN          NaN       NaN          NaN         NaN
# 215            NaN          NaN       NaN          NaN         NaN
# 221            NaN          NaN       NaN          NaN         NaN
# 222            NaN          NaN       NaN          NaN         NaN
# 226            NaN          NaN       NaN          NaN         NaN
# 227            NaN          NaN       NaN          NaN         NaN
# 237            NaN          NaN       NaN          NaN         NaN
# 240            NaN          NaN       NaN          NaN         NaN
# 267            NaN          NaN       NaN          NaN         NaN
# 279            NaN          NaN       NaN          NaN         NaN
# 283            NaN          NaN       NaN          NaN         NaN
# 286            NaN          NaN       NaN          NaN         NaN
# 290            NaN          NaN       NaN          NaN         NaN
# 313            NaN          NaN       NaN          NaN         NaN
# 149                      NaN                       NaN
# 178                      NaN                       NaN
# 186                      NaN                       NaN
# 199                      NaN                       NaN
# 215                      NaN                       NaN
# 221                      NaN                       NaN
# 222                      NaN                       NaN
# 226                      NaN                       NaN
# 227                      NaN                       NaN
# 237                      NaN                       NaN
# 240                      NaN                       NaN
# 267                      NaN                       NaN
# 279                      NaN                       NaN
# 283                      NaN                       NaN
# 286                      NaN                       NaN
# 290                      NaN                       NaN
# 313                      NaN                       NaN
# 324                      NaN                       NaN
# 325                      NaN                       NaN
# 326                      NaN                       NaN
# ...                      ...                       ...
# 1259762                  NaN                       NaN
# 1259773                  NaN                       NaN
# 1259781                  NaN                       NaN
# 1259815                  NaN                       NaN
# 1259845                  NaN                       NaN
# 1259851                  NaN                       NaN
# 1259876                  NaN                       NaN
# 1259915                  NaN                       NaN
# 1259923                  NaN                       NaN
# 1259941                  NaN                       NaN
# 1259960                  NaN                       NaN
# 1259961                  NaN                       NaN
# 1259963                  NaN                       NaN
# 1259971                  NaN                       NaN
# 1259981                  NaN                       NaN
# 1260025                  NaN                       NaN
# 1260026                  NaN                       NaN
# 1260039                  NaN                       NaN
# 1260040                  NaN                       NaN
# 1260047                  NaN                       NaN
# 1260049                  NaN                       NaN
# 1260050                  NaN                       NaN
# 1260054                  NaN                       NaN
# 1260071                  NaN                       NaN
# 1260080                  NaN                       NaN
# 1260092                  NaN                       NaN
# 1260098                  NaN                       NaN
# 1260107                  NaN                       NaN
# 1260122                  NaN                       NaN
# 1260154                  NaN                       NaN
#
# [114663 rows x 1118 columns]

# %% [markdown]
# ### Principal Component Analysis (PCA)

# %%
pca = PCA(n_components=5)
X_train_pca = pca.fit_transform(X_train_10pcnt_scaled)
X_train_pca
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-720631efc3d1> in <module>
#       1 pca = PCA(n_components=5)
# ----> 2 X_train_pca = pca.fit_transform(X_train_10pcnt_scaled)
#       3 X_train_pca
#
# ~/.local/lib/python3.5/site-packages/sklearn/decomposition/pca.py in fit_transform(self, X, y)
#     358
#     359         """
# --> 360         U, S, V = self._fit(X)
#     361         U = U[:, :self.n_components_]
#     362
#
# ~/.local/lib/python3.5/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     380
#     381         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 382                         copy=self.copy)
#     383
#     384         # Handle n_components==None
#
# ~/.local/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~/.local/lib/python3.5/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
pca.explained_variance_ratio_

# %%
pca.components_

# %% [markdown]
# ## Classification Modeling (Fully Paid = 1, Charged-Off = 0)

# %% [markdown]
# #### Logistic Regression v1

# %% [markdown]
# ## Use Model #1: Classification Model to Filter Rows for Model #2: Regression on IRR
# - I will use my predicted classification from Model #1 on train set to feed to Model #2, rather than filtering using pre-labelled classes
# - This is what I would need to do with new, real-world data so my training process should mimic this

# %% [markdown]
# ## IRR Target Variable Calculation/Extrapolation

# %%
#calculating NAR
lc_df[['total_rec_int','total_rec_late_fee','installment','collection_recovery_fee','out_prncp','loan_status']].head(5)

# %%
lc_df['last_pymnt_d'].head()

# %%
lc_df['last_payment_date'] = lc_df['last_pymnt_d'].str[:3]+'/'+'1'+'/'+lc_df['last_pymnt_d'].str[4:]
lc_df['issue_date'] = lc_df['issue_d'].str[:3]+'/'+'1'+'/'+lc_df['issue_d'].str[4:]

# %%
lc_df['last_payment_date'] = lc_df['last_payment_date'].astype(str)
lc_df['issue_date'] = lc_df['issue_date'].astype(str)

# %%
lc_df = lc_df[lc_df['last_payment_date'] != 'nan'].reset_index()

# %%
lc_df['last_payment_date'][1319]

# %%
from datetime import datetime

lc_df['last_payment_date_dt'] = lc_df['last_payment_date'].map(lambda x: datetime.strptime(x,'%b/%d/%Y'))
lc_df['issue_date_dt'] = lc_df['issue_date'].map(lambda x: datetime.strptime(x,'%b/%d/%Y'))

# %%
lc_df['issue_date_dt'].tail()

# %%
lc_df['days_btwn_funding_lastpayment'] = (lc_df['last_payment_date_dt'].dt.date -
                                          lc_df['issue_date_dt'].dt.date).dt.days

# %%
#raw_lc_df['y_stanford'] = (raw_lc_df['total_pymnt']/raw_lc_df['funded_amnt'])-1

# %%
lc_df[['addr_state','annual_inc','collection_recovery_fee','emp_title',
           'fico_range_high','fico_range_low','funded_amnt','grade','home_ownership',
           'int_rate','loan_amnt','loan_status','purpose','sub_grade','title','total_rec_int',
           'total_rec_late_fee','total_rec_prncp','zip_code','debt_settlement_flag','out_prncp',
           'collection_recovery_fee','days_btwn_funding_lastpayment','y_stanford']][lc_df['loan_status'] == 1].tail(5)

# %%
# for i in range(50): 
#     if raw_lc_df.loc[i,'loan_status'] != 'Charged Off':
#         raw_lc_df.loc[i,'NAR_test'] = ((1+((((raw_lc_df['total_rec_int'][i] #(interest received
#                                     +raw_lc_df['total_rec_late_fee'][i] # + late fees received
#                                     -(0.01*raw_lc_df['installment'][i]) # - service fee paid
#                                     +((raw_lc_df['collection_recovery_fee'][i]/.4)*.6) # + collection fees received
#                                     - 0) # - 0 or out.principal
#                                  /(raw_lc_df['out_prncp'][i])) #ALL THE ABOVE divided by out.principal
#                                     *raw_lc_df['out_prncp'][i]) #FRACTION ABOVE times out.principal
#                                  / (raw_lc_df['out_prncp'][i])))**12)-1 #TERM ABOVE divided by out.principal, 
#                                                                     #& EVERYTHING to the power of 12 & ALL OF THAT minus 1
#     else: 
#         raw_lc_df.loc[i,'NAR_test'] = ((1+((((raw_lc_df['total_rec_int'][i] #(interest received
#                                     +raw_lc_df['total_rec_late_fee'][i] # + late fees received
#                                     -(0.01*raw_lc_df['installment'][i]) # - service fee paid
#                                     +((raw_lc_df['collection_recovery_fee'][i]/.4)*.6) # + collection fees received
#                                     - raw_lc_df['out_prncp'][i]) # - 0 or out.principal
#                                  /(raw_lc_df['out_prncp'][i])) #ALL THE ABOVE divided by out.principal
#                                     *raw_lc_df['out_prncp'][i]) #FRACTION ABOVE times out.principal
#                                  / (raw_lc_df['out_prncp'][i])))**12)-1 #TERM ABOVE divided by out.principal, 
#                                                                     #& EVERYTHING to the power of 12 & ALL OF THAT minus 1
#     print('row completed')

# %%
lc_df.head(10)

# %%
lc_df['loan_status'].value_counts()
